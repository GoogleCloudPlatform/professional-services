# %%
# !pip install google-cloud-vision
# Out:
# Requirement already satisfied: google-cloud-vision in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (0.36.0)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.6.0 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-cloud-vision) (1.7.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (2.21.0)
# Requirement already satisfied: protobuf>=3.4.0 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (3.6.1)
# Requirement already satisfied: googleapis-common-protos!=1.5.4,<2.0dev,>=1.5.3 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (1.5.8)
# Requirement already satisfied: setuptools>=34.0.0 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (40.8.0)
# Requirement already satisfied: google-auth<2.0dev,>=0.4.0 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (1.6.3)
# Requirement already satisfied: pytz in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (2018.9)
# Requirement already satisfied: six>=1.10.0 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (1.12.0)
# Requirement already satisfied: grpcio>=1.8.2; extra == "grpc" in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (1.18.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (2018.11.29)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (3.1.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (0.2.4)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.1 in /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-vision) (0.4.5)

# %%
from google.cloud import vision
import io
import numpy as np
import pandas as pd
import json

# %%
def corners(element):
    """Calculate four edges ((top, bottom, left, right)) of word from Vision API output
    Args:
    element: tuple representing word on document (word, y, x, height, width)

    Returns:
    top: y-coordinate of top of word
    bottom: y-coordinate of bottom of word
    left: x-coordinate of leftmost part of word
    right: x-coordinate of rightmost part of word
    """
    top = element[1]
    bottom  = top + element[3]
    left = element[2]
    right = left + element[4]
    return top, bottom, left, right

def distance(word_a, word_b):
    """Calculate the x and y distance between the given two words
    Args:
    word_a: first word element (word, y, x, height, width)
    word_b: second word element (word, y, x, height, width)
    Returns:
    x-, y-distance between word_a and word_b
    """
    top_a, bottom_a, left_a, right_a = corners(word_a)
    top_b, bottom_b, left_b, right_b = corners(word_b)
    x = left_b - right_a
    y = bottom_a - top_b
    return x, y


def sort_words(input_list, buffer):
    """Sort the words by y-coordinate and then x-coordinate. 
    Ensure that words that share the same line (overlap on the y-axis) are ordered left-to-right
    
    Args: 
    input_list: list of elements (word, y, x, height, width) in original (Vision API output) order
    buffer: minimizes the width (and height) that is considered an overlap. Adjusting the buffer is helpful in scenarios where the image is slightly 
    rotated or the fields are not perfectly aligned
    Returns:
    ordered: array sorted by y and then x axis
    a: array with new indices of each word
    ordered[a] gives sorted list

    """
    ordered = np.sort(input_list, axis = 0, order = ['y', 'x']) #sort input by y-axis and then x-axis
    a = np.arange(len(ordered)) #array of indices in order to re-order the words. ordered[a] will be the sorted output
    for i in range(len(ordered)):
        top, bottom, left, right = corners(ordered[a][i])
        k = i + 1
        j = 1
        while (k < len(ordered)) and ((ordered[a][k][1] + buffer) < bottom):
            if ((ordered[a][k][2] + buffer) < left):
                current = a[i]
                top, bottom, left, right = corners(ordered[a][k])
                a[i] = a[k] #swap locations (by moving the order of the indices)
                a[k] = current
                k = i + 1
                j += 1
            else:
                k += 1
    return ordered[a]

def line_by_line(list):
    '''Format and print the list, adding new lines and indents'''
    i = 0 #first word's leftmost x-coordinate
    right = 2000
    output = []
    sentence = ""
    leftmost = 0
    rightmost = 0
    for o in list:
        left = corners(o)[2]
        if i > o['x']: #new line
            rightmost = right
            if len(sentence.strip()) > 0:
                output.append([sentence.strip(), leftmost, rightmost])
            sentence = ""
            leftmost = left
        else:
            diff = (left - right) / 50
            if diff > 1:
                if len(sentence.strip()) > 0:
                    output.append([sentence.strip(), leftmost, rightmost])
                sentence = ""
                leftmost = left
        sentence = sentence + " "+str(np.char.decode(o[0]))
        i = o['x']
        right = corners(o)[3]
    return output

def create_word_vertex_pairs(texts):
    pageNumber = 0
    results = []
    resultList = []
    for text in texts:
        verticesList = text.bounding_poly.vertices
        x_a = verticesList[0].x 
        y_a = verticesList[0].y 
        x_b = verticesList[2].x
        y_b = verticesList[2].y
        word = text.description
        if len(word) > 0:
            #vision API considers each punctuation character its own word. Removing extraneous punctuation improves searching/parsing
            if word not in [':',"|","'","?",";",",","(",")","#","."]:
                word = word.encode('ascii',errors='ignore')
                c = tuple((word.lower(), min(y_a, y_b), min(x_a, x_b), abs(y_b - y_a), abs(x_b - x_a))) #Word, topmost-y, leftmost-x, height, width
                resultList.append(c) #each page should have its own list of words + coordinates (to allow sorting)
    input = np.asarray(resultList, dtype = [('word', 'S25'), ('y', 'int64'), ('x', 'int64'), ('height', 'int64'), ('width', 'int64')])
    results.append(input) #add each page's list to output
    return results

def format_print(list):
    '''Format and print the list, adding new lines and indents'''
    i = 0 #first word's leftmost x-coordinate
    right = 2000
    for o in list:
        left = corners(o)[2]
        if i > o['x']: #new line
            print("")
        else:
            diff = (left - right) / 50
            for n in range(int(diff)): #indent
                print("\t\t", end = "")
        print(np.char.decode(o[0]), end = " ")
        i = o['x']
        right = corners(o)[3]

# %% [markdown]
# ### Get response from Vision API OCR

# %%
path = '/usr/local/google/home/fprost/Downloads/us_047.jpg'
client = vision.ImageAnnotatorClient()

with io.open(path, 'rb') as image_file:
    content = image_file.read()

image = vision.types.Image(content=content)

response = client.document_text_detection(image=image)
# Out:
# /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %% [markdown]
# ### Sort words (Within a column)

# %%
words_and_vertices[:10]
# Out:
# [array([(b'10martin\nde noel om w mit',   44,  216, 1983, 1250),
#         (b'10',   44,  828,   64,   24),
#         (b'martin',   44,  884,   64,   82),
#         (b'de',   44,  950,   64,  117), (b'noel',   44, 1057,   64,   78),
#         (b'om',   44, 1141,   64,   47), (b'w',   44, 1198,   64,   18),
#         (b'mit',   44, 1231,   64,   37),
#         (b'untut',   44, 1276,   64,   83),
#         (b'us010143012b2',  108, 1055,   23,  196),
#         (b'12',  190,  225,   44,   24),
#         (b'united',  190,  270,   44,  134),
#         (b'states',  190,  438,   44,  121),
#         (b'patent',  190,  580,   44,  139),
#         (b'stattin',  242,  274,   32,   86),
#         (b'et',  242,  380,   32,   24), (b'al',  242,  416,   32,   28),
#         (b'10',  200,  910,   34,   19),
#         (b'patent',  199,  957,   34,   90),
#         (b'no',  199, 1055,   34,   44), (b'us',  198, 1169,   34,   50),
#         (b'10',  197, 1237,   34,   31), (b'143',  197, 1286,   34,   53),
#         (b'012',  196, 1350,   35,   54), (b'b2',  196, 1424,   34,   37),
#         (b'45',  242,  906,   31,   22), (b'date',  242,  955,   31,   60),
#         (b'of',  242, 1030,   31,   28),
#         (b'patent',  242, 1070,   31,   91),
#         (b'nov',  242, 1267,   31,   54), (b'27',  242, 1344,   31,   28),
#         (b'2018',  242, 1396,   31,   58), (b'54',  331,  225,   24,   22),
#         (b'random',  331,  283,   24,  105),
#         (b'access',  331,  406,   24,   94),
#         (b'procedure',  331,  512,   24,  156),
#         (b'in',  331,  682,   24,   13),
#         (b'wireless',  360,  278,   25,  132),
#         (b'device',  360,  421,   25,   91),
#         (b'radio',  360,  533,   25,   74),
#         (b'base',  360,  626,   25,   57),
#         (b'station',  360,  698,   25,  101),
#         (b'and',  390,  283,   21,   48),
#         (b'methods',  390,  341,   21,  127),
#         (b'therein',  390,  483,   21,  102),
#         (b'52',  325,  872,   34,   27), (b'u',  324,  934,   35,   10),
#         (b's',  323,  956,   35,   10), (b'ci',  322,  987,   34,   27),
#         (b'cpc',  358,  932,   22,   38),
#         (b'h04w',  358, 1037,   22,   56), (b'74',  358, 1113,   22,   21),
#         (b'/',  358, 1138,   22,    5), (b'0833',  358, 1142,   22,   48),
#         (b'2013',  358, 1210,   22,   47), (b'01',  358, 1266,   22,   24),
#         (b'h04l',  358, 1316,   22,   56), (b'41',  358, 1381,   22,   28),
#         (b'/',  358, 1407,   22,    5), (b'0654',  358, 1415,   22,   45),
#         (b'2013',  386, 1122,   21,   45), (b'01',  386, 1178,   21,   23),
#         (b'h04w',  386, 1229,   21,   55), (b'74',  386, 1302,   21,   19),
#         (b'/',  386, 1326,   21,    5), (b'08',  386, 1333,   21,   19),
#         (b'2013',  386, 1375,   21,   45), (b'01',  386, 1429,   21,   26),
#         (b'58',  411,  872,   29,   21),
#         (b'field',  411,  935,   29,   43),
#         (b'of',  411,  995,   29,   21),
#         (b'classification',  411, 1024,   29,  135),
#         (b'search',  411, 1175,   29,   65),
#         (b'none',  440,  930,   22,   54),
#         (b'see',  468,  933,   23,   30),
#         (b'application',  468,  977,   23,  108),
#         (b'file',  468, 1096,   23,   26),
#         (b'for',  468, 1136,   23,   26),
#         (b'complete',  468, 1174,   23,   86),
#         (b'search',  468, 1272,   23,   58),
#         (b'history',  468, 1343,   23,   66),
#         (b'71',  441,  224,   26,   23),
#         (b'applicant',  441,  286,   26,   95),
#         (b'telefonaktiebolaget',  441,  407,   26,  201),
#         (b'l',  441,  619,   26,    7), (b'm',  441,  641,   26,    7),
#         (b'ericsson',  441,  675,   26,   81),
#         (b'publ',  470,  409,   23,   47),
#         (b'stockholm',  470,  481,   23,   93),
#         (b'se',  470,  602,   23,   26), (b'56',  523,  873,   21,   19),
#         (b'references',  520, 1072,   23,  114),
#         (b'cited',  520, 1197,   23,   54), (b'u',  565, 1012,   27,    7),
#         (b's',  565, 1037,   27,    7),
#         (b'patent',  565, 1063,   27,   94),
#         (b'documents',  565, 1163,   27,  152),
#         (b'72',  523,  224,   23,   21),
#         (b'inventors',  523,  284,   23,   90),
#         (b'magnus',  523,  394,   23,   89),
#         (b'stattin',  523,  495,   23,   63),
#         (b'upplands',  523,  576,   23,   99),
#         (b'vsby',  523,  688,   23,   54), (b'se',  523,  761,   23,   26),
#         (b'gunnar',  551,  396,   24,   85),
#         (b'bergquist',  551,  493,   24,  102),
#         (b'kista',  551,  611,   24,   48),
#         (b'se',  551,  678,   24,   27), (b'tao',  551,  738,   24,   31),
#         (b'cui',  579,  398,   23,   40),
#         (b'upplands',  579,  451,   23,   95),
#         (b'vsby',  579,  558,   23,   56), (b'se',  579,  634,   23,   26),
#         (b'mats',  579,  681,   23,   59),
#         (b'folke',  579,  749,   23,   56),
#         (b'vllingby',  606,  403,   24,   91),
#         (b'se',  606,  513,   24,   27),
#         (b'gunnar',  606,  565,   24,   84),
#         (b'mildh',  606,  655,   24,   64),
#         (b'sollentuna',  634,  398,   24,  105),
#         (b'se',  634,  522,   24,   27),
#         (b'elena',  634,  578,   24,   55),
#         (b'myhre',  634,  642,   24,   73),
#         (b'jrflla',  634,  733,   24,   68),
#         (b'se',  662,  407,   24,   27),
#         (b'mikael',  662,  457,   24,   76),
#         (b'wittberg',  662,  543,   24,   95),
#         (b'uppsala',  662,  655,   24,   79),
#         (b'se',  662,  752,   24,   27), (b'2009',  618,  877,   20,   43),
#         (b'/',  618,  921,   20,    5),
#         (b'0186624',  618,  928,   20,   72),
#         (b'al',  618, 1016,   20,   30), (b'*',  618, 1049,   20,    5),
#         (b'7',  618, 1089,   20,    5), (b'/',  618, 1098,   20,    5),
#         (b'2009',  618, 1102,   20,   42),
#         (b'cave',  618, 1164,   20,   46),
#         (b'2010',  665,  877,   20,   42), (b'/',  665,  921,   20,    5),
#         (b'0202288',  665,  928,   20,   75),
#         (b'a1',  665, 1019,   20,   26), (b'*',  665, 1049,   20,    5),
#         (b'8',  665, 1089,   20,    5), (b'/',  665, 1098,   20,    5),
#         (b'2010',  665, 1103,   20,   41),
#         (b'park',  665, 1165,   20,   34),
#         (b'ho4l',  620, 1342,   18,   49), (b'1',  620, 1405,   18,    4),
#         (b'/',  620, 1413,   18,    4), (b'1887',  620, 1421,   18,   41),
#         (b'455',  644, 1390,   18,   31), (b'/',  644, 1425,   18,    4),
#         (b'450',  644, 1430,   18,   29),
#         (b'h04w',  666, 1348,   19,   51), (b'48',  666, 1413,   19,   21),
#         (b'/',  666, 1435,   19,    5), (b'08',  666, 1441,   19,   21),
#         (b'370',  690, 1393,   21,   27), (b'/',  690, 1425,   21,    5),
#         (b'230',  690, 1429,   21,   31), (b'73',  714,  224,   23,   21),
#         (b'assignee',  714,  282,   23,   87),
#         (b'telefonaktiebolaget',  714,  402,   23,  205),
#         (b'lm',  714,  617,   23,   26),
#         (b'ericsson',  714,  665,   23,   87),
#         (b'publ',  742,  409,   23,   47),
#         (b'stockholm',  742,  481,   23,   93),
#         (b'se',  742,  602,   23,   26),
#         (b'continued',  717, 1112,   27,  100),
#         (b'foreign',  772,  981,   20,  100),
#         (b'patent',  772, 1095,   20,   91),
#         (b'documents',  772, 1193,   20,  155),
#         (b'*',  794,  232,   23,    6),
#         (b'notice',  794,  281,   23,   66),
#         (b'subject',  794,  401,   23,   73),
#         (b'to',  794,  482,   23,   12), (b'any',  794,  507,   23,   34),
#         (b'disclaimer',  794,  547,   23,  105),
#         (b'the',  794,  664,   23,   30),
#         (b'term',  794,  699,   23,   36), (b'of',  794,  750,   23,   26),
#         (b'this',  794,  779,   23,   32),
#         (b'patent',  824,  399,   22,   62),
#         (b'is',  823,  472,   22,   12),
#         (b'extended',  823,  498,   22,   87),
#         (b'or',  822,  600,   22,   19),
#         (b'adjusted',  822,  629,   22,   80),
#         (b'under',  821,  724,   23,   53),
#         (b'35',  821,  793,   22,   20), (b'u',  850,  399,   25,    6),
#         (b's',  850,  425,   25,    6), (b'c',  850,  446,   25,    6),
#         (b'154',  850,  480,   25,   28), (b'b',  850,  521,   25,    6),
#         (b'by',  850,  548,   25,   23), (b'231',  850,  586,   25,   32),
#         (b'days',  850,  628,   25,   43), (b'gb',  824,  862,   14,   29),
#         (b'2461780',  817, 1029,   27,   75),
#         (b'a',  817, 1119,   27,    7), (b'1',  817, 1189,   27,    7),
#         (b'/',  817, 1197,   27,    7), (b'2010',  817, 1206,   27,   37),
#         (b'other',  880, 1029,   23,   78),
#         (b'publications',  880, 1123,   23,  176),
#         (b'21',  899,  224,   31,   22), (b'appl',  899,  284,   31,   49),
#         (b'no',  899,  348,   31,   28), (b'22',  946,  227,   35,   19),
#         (b'pct',  947,  283,   35,   45),
#         (b'filed',  947,  338,   36,   43),
#         (b'86',  998,  227,   35,   19), (b'pct',  999,  283,   35,   45),
#         (b'no',  999,  336,   35,   32), (b'$', 1047,  286,   29,    8),
#         (b'371', 1047,  303,   29,   38), (b'c', 1047,  358,   29,    8),
#         (b'1', 1047,  388,   29,    8), (b'2', 1075,  292,   29,    8),
#         (b'date', 1075,  319,   29,   46), (b'14',  899,  453,   31,   16),
#         (b'/',  899,  475,   31,    8), (b'892',  899,  480,   31,   36),
#         (b'690',  899,  525,   31,   36), (b'may',  949,  449,   35,   45),
#         (b'21',  949,  506,   35,   26), (b'2014',  950,  547,   35,   45),
#         (b'pct', 1000,  452,   35,   50), (b'/', 1001,  500,   35,    9),
#         (b'se2014', 1000,  506,   37,   78),
#         (b'/', 1001,  587,   35,    9),
#         (b'050621', 1001,  593,   37,   76),
#         (b'unknown',  928,  861,   24,   90),
#         (b'author',  928,  968,   24,   61),
#         (b'"',  928, 1042,   24,    6), (b'3gpp',  928, 1054,   24,   49),
#         (b'ts',  928, 1119,   24,   18), (b'36',  928, 1153,   24,   13),
#         (b'321',  928, 1179,   24,   31), (b'v11',  928, 1220,   24,   34),
#         (b'2',  928, 1265,   24,    6), (b'0',  928, 1280,   24,    6),
#         (b'mar',  928, 1303,   24,   41),
#         (b'2013',  928, 1359,   24,   40), (b'"',  928, 1410,   24,    6),
#         (b'3rd',  928, 1438,   24,   24),
#         (b'generation',  957,  862,   22,   96),
#         (b'partnership',  957,  969,   22,   93),
#         (b'project',  957, 1071,   22,   60),
#         (b'technical',  957, 1145,   22,   84),
#         (b'specification',  957, 1232,   22,  113),
#         (b'group',  957, 1351,   22,   54),
#         (b'radio',  957, 1411,   22,   49),
#         (b'access',  986,  865,   22,   63),
#         (b'network',  986,  940,   22,   74),
#         (b'evolved',  986, 1041,   22,   71),
#         (b'universal',  986, 1128,   22,   87),
#         (b'terrestrial',  986, 1230,   22,   91),
#         (b'radio',  986, 1336,   22,   47),
#         (b'access',  986, 1401,   22,   63),
#         (b'e', 1013,  875,   21,    5), (b'-', 1013,  886,   21,    5),
#         (b'utra', 1013,  889,   21,   60),
#         (b'medium', 1013,  971,   21,   68),
#         (b'access', 1013, 1056,   21,   60),
#         (b'control', 1013, 1125,   21,   66),
#         (b'mac', 1013, 1204,   21,   48),
#         (b'protocol', 1013, 1271,   21,   74),
#         (b'specification', 1013, 1354,   21,  108),
#         (b'release', 1039,  870,   25,   69),
#         (b'11', 1039,  953,   25,   14), (b'mar', 1039,  988,   25,   40),
#         (b'2013', 1039, 1041,   25,   39), (b'pp', 1039, 1094,   25,   23),
#         (b'1', 1039, 1135,   25,    6), (b'-', 1039, 1143,   25,    6),
#         (b'56', 1039, 1151,   25,   14),
#         (b'continued', 1071, 1113,   23,   98),
#         (b'nov', 1075,  448,   29,   41), (b'20', 1075,  508,   29,   16),
#         (b'2015', 1075,  546,   29,   45), (b'87', 1127,  225,   29,   21),
#         (b'pct', 1127,  285,   29,   42), (b'pub', 1127,  335,   29,   37),
#         (b'no', 1127,  388,   29,   32),
#         (b'w02014', 1127,  448,   29,   92),
#         (b'/', 1127,  544,   29,    8),
#         (b'189453', 1127,  552,   29,   74),
#         (b'pct', 1171,  281,   22,   48), (b'pub', 1171,  338,   22,   32),
#         (b'date', 1171,  389,   22,   43),
#         (b'nov', 1171,  449,   22,   41), (b'27', 1171,  506,   22,   19),
#         (b'2014', 1171,  548,   22,   42),
#         (b'primary', 1125,  867,   23,   79),
#         (b'examiner', 1125,  959,   23,   92),
#         (b'-', 1125, 1066,   23,    6),
#         (b'george', 1125, 1085,   23,   75),
#         (b'c', 1125, 1171,   23,    6),
#         (b'atkins', 1125, 1195,   23,   63),
#         (b'74', 1155,  873,   23,   21),
#         (b'attorney', 1155,  921,   23,   81),
#         (b'agent', 1155, 1019,   23,   58),
#         (b'or', 1155, 1093,   23,   17), (b'firm', 1155, 1123,   23,   37),
#         (b'', 1155, 1183,   23,    6), (b'murphy', 1155, 1203,   23,   81),
#         (b'bilak', 1155, 1299,   23,   48), (b'&', 1155, 1364,   23,    6),
#         (b'homiller', 1181,  866,   25,   86),
#         (b'pllc', 1181,  968,   25,   55), (b'65', 1226,  222,   21,   23),
#         (b'prior', 1223,  427,   23,   53),
#         (b'publication', 1223,  492,   23,  115),
#         (b'data', 1223,  620,   23,   49), (b'us', 1261,  281,   29,   32),
#         (b'2016', 1261,  326,   29,   40), (b'/', 1261,  371,   29,    8),
#         (b'0105912', 1261,  378,   29,   84),
#         (b'a1', 1261,  477,   29,   27), (b'apr', 1261,  552,   29,   33),
#         (b'14', 1261,  605,   29,   16), (b'2016', 1261,  644,   29,   40),
#         (b'related', 1352,  353,   22,   78),
#         (b'u', 1352,  447,   22,    5), (b's', 1352,  470,   22,    5),
#         (b'application', 1352,  496,   22,  115),
#         (b'data', 1352,  626,   22,   48), (b'60', 1391,  224,   27,   20),
#         (b'provisional', 1391,  282,   27,  113),
#         (b'application', 1391,  405,   27,  103),
#         (b'no', 1391,  519,   27,   30), (b'61', 1391,  558,   27,   30),
#         (b'/', 1391,  587,   27,    7), (b'825', 1391,  593,   27,   35),
#         (b'593', 1391,  638,   27,   35),
#         (b'filed', 1391,  692,   27,   37),
#         (b'on', 1391,  740,   27,   20), (b'may', 1391,  766,   27,   47),
#         (b'21', 1420,  281,   23,   26), (b'2013', 1420,  323,   23,   44),
#         (b'57', 1235,  874,   27,   20),
#         (b'abstract', 1233, 1099,   25,  133),
#         (b'embodiments', 1272,  866,   25,  135),
#         (b'herein', 1272, 1014,   25,   56),
#         (b'relate', 1272, 1092,   25,   49),
#         (b'to', 1272, 1159,   25,   14), (b'a', 1272, 1190,   25,    6),
#         (b'wireless', 1272, 1211,   25,   79),
#         (b'device', 1272, 1305,   25,   60),
#         (b'10', 1272, 1391,   25,   23), (b'for', 1272, 1437,   25,   29),
#         (b'handling', 1302,  864,   24,   88),
#         (b'access', 1302,  962,   24,   63),
#         (b'to', 1302, 1039,   24,   13), (b'a', 1302, 1068,   24,    6),
#         (b'radio', 1302, 1089,   24,   42),
#         (b'base', 1302, 1146,   24,   44),
#         (b'station', 1302, 1206,   24,   60),
#         (b'12', 1302, 1289,   24,   22), (b'in', 1302, 1334,   24,   13),
#         (b'a', 1302, 1363,   24,    6),
#         (b'wireless', 1302, 1383,   24,   80),
#         (b'communication', 1330,  864,   22,  151),
#         (b'network', 1330, 1026,   22,   78),
#         (b'1', 1330, 1128,   22,    5), (b'the', 1330, 1161,   22,   28),
#         (b'wireless', 1330, 1196,   22,   81),
#         (b'device', 1330, 1287,   22,   62),
#         (b'10', 1330, 1371,   22,   16),
#         (b'being', 1330, 1406,   22,   56),
#         (b'configured', 1357,  867,   25,  101),
#         (b'to', 1357,  978,   25,   18),
#         (b'initiate', 1386,  891,   23,   66),
#         (b'a', 1386,  970,   23,    6),
#         (b'random', 1386,  989,   23,   65),
#         (b'access', 1386, 1074,   23,   61),
#         (b'procedure', 1386, 1146,   23,   97),
#         (b'in', 1386, 1256,   23,   12), (b'the', 1386, 1281,   23,   30),
#         (b'wireless', 1386, 1321,   23,   80),
#         (b'com', 1386, 1412,   23,   49),
#         (b'munication', 1413,  911,   23,  110),
#         (b'network', 1413, 1033,   23,   79),
#         (b'1', 1413, 1137,   23,    6),
#         (b'determine', 1440,  888,   24,  100),
#         (b'that', 1440,  998,   24,   37), (b'a', 1440, 1045,   24,    6),
#         (b'problem', 1440, 1061,   24,   74),
#         (b'with', 1440, 1152,   24,   39),
#         (b'the', 1440, 1206,   24,   31),
#         (b'random', 1440, 1246,   24,   65),
#         (b'access', 1440, 1330,   24,   60),
#         (b'proce', 1440, 1402,   24,   60),
#         (b'dure', 1468,  915,   24,   41),
#         (b'has', 1468,  965,   24,   35),
#         (b'occurred', 1468, 1009,   24,   80),
#         (b'when', 1468, 1098,   24,   51), (b'a', 1468, 1162,   24,    6),
#         (b'certain', 1468, 1181,   24,   62),
#         (b'condition', 1468, 1256,   24,   89),
#         (b'is', 1468, 1357,   24,   13),
#         (b'fulfilled', 1468, 1379,   24,   75),
#         (b'and', 1497,  914,   21,   33),
#         (b'continued', 1528, 1137,   25,  101),
#         (b'51', 1472,  223,   24,   26), (b'int', 1472,  286,   24,   27),
#         (b'cl', 1472,  330,   24,   27), (b'h04w', 1499,  283,   25,   56),
#         (b'74', 1499,  357,   25,   23), (b'/', 1499,  383,   25,    6),
#         (b'08', 1499,  389,   25,   23), (b'h04l', 1530,  281,   21,   56),
#         (b'12', 1530,  352,   21,   19), (b'/', 1530,  375,   21,    5),
#         (b'24', 1530,  380,   21,   23), (b'2009', 1502,  525,   21,   46),
#         (b'01', 1502,  579,   21,   23), (b'2006', 1530,  526,   22,   42),
#         (b'01', 1530,  580,   22,   24), (b'dr10', 1651,  652,    9,   89),
#         (b'301', 1739,  759,   18,   27),
#         (b'initiate', 1739,  793,   18,   42),
#         (b'ra', 1739,  843,   18,   16),
#         (b'procedure', 1739,  869,   18,   65),
#         (b'302', 1786,  631,   17,   22),
#         (b'select', 1786,  664,   17,   39),
#         (b'ra', 1786,  710,   17,   18),
#         (b'preamble', 1806,  647,   17,   60),
#         (b'303', 1849,  605,   17,   22),
#         (b'determine', 1849,  638,   19,   68),
#         (b'problem', 1850,  713,   19,   46),
#         (b'with', 1870,  621,   16,   24), (b'ra', 1870,  654,   16,   17),
#         (b'procedure', 1870,  678,   16,   67),
#         (b'304', 1908,  610,   18,   21),
#         (b'perform', 1908,  643,   20,   46),
#         (b'an', 1909,  701,   18,   12),
#         (b'action', 1910,  724,   18,   36),
#         (b'3041', 1936,  648,   18,   32),
#         (b'delay', 1936,  690,   18,   37),
#         (b'3042', 1973,  651,   16,   31),
#         (b'abort', 1973,  690,   16,   38),
#         (b'3043', 2009,  651,   18,   34),
#         (b'stop', 2009,  695,   18,   27)],
#        dtype=[('word', 'S25'), ('y', '<i8'), ('x', '<i8'), ('height', '<i8'), ('width', '<i8')])]

# %%
texts = response.text_annotations
words_and_vertices = create_word_vertex_pairs(texts)
output = sort_words(words_and_vertices[0], buffer = 0)

# %%
format_print(output)
# Out:
# 10martin
# de noel om w mit 10 martin de noel om w mit untut
# us010143012b2
# 12 united states patent 						10 patent no 		us 10 143 012 b2
# stattin et al 																		45 date of patent 				nov 27 2018
# 54 random access procedure in 						52
# wireless device 																s ci
# radio base station 				cpc u 		h04w 74 / 0833 2013 01 h04l 41 / 0654
# and methods therein 																				2013 01 h04w 74 / 08 2013 01
# 58 field of classification search
# 71 applicant telefonaktiebolaget l m ericsson 						none
# publ stockholm se 												see application file for complete search history
# 72 inventors magnus stattin upplands vsby se 		56 						references cited
# gunnar bergquist kista se tao
# cui upplands vsby se mats folke 								u s patent documents
# vllingby se gunnar mildh
# sollentuna se elena myhre jrflla 		2009 / 0186624 al * 7 / 2009 cave 				ho4l 1 / 1887
# 455 / 450
# se mikael wittberg uppsala se 		2010 / 0202288 a1 * 8 / 2010 park 				h04w 48 / 08
# 370 / 230
# 73 assignee telefonaktiebolaget lm ericsson
# publ stockholm se 																		continued
# foreign patent documents
# * notice 		subject to any disclaimer the term of this
# patent is extended or adjusted under 35 gb 				2461780 a 		1 / 2010
# u s c 154 b by 231 days
# 21 appl no 		14 / 892 690 																		other publications
# 22 pct filed 		may 21 2014 										unknown author " 3gpp ts 36 321 v11 2 0 mar 2013 " 3rd
# generation partnership project technical specification group radio
# 86 pct no 		pct / se2014 / 050621 						access network evolved universal terrestrial radio access
# e - utra medium access control mac protocol specification
# $ 2 371 date 																				release 11 mar 2013 pp 1 - 56
# c 1 		nov 20 2015 																				continued
# 87 pct pub no w02014 / 189453 								primary examiner - george c atkins
# pct pub date nov 27 2014 										74 attorney agent or firm  murphy bilak &
# homiller pllc
# 65 						prior publication data
# us 2016 / 0105912 a1 apr 14 2016 						57 								abstract
# embodiments herein relate to a wireless device 10 for
# handling access to a radio base station 12 in a wireless
# communication network 1 the wireless device 10 being
# related u s application data 						configured to
# 60 provisional application no 61 / 825 593 filed on may 		initiate a random access procedure in the wireless com
# 21 2013 																				munication network 1
# determine that a problem with the random access proce
# 51 int cl 																						dure has occurred when a certain condition is fulfilled
# h04w 74 / 08 				2009 01 												and
# h04l 12 / 24 				2006 01 																				continued
# dr10 301 initiate ra procedure
# 302 select ra
# preamble
# 303 determine problem
# with ra procedure
# 304 perform an action
# 3041 delay
# 3042 abort
# 3043 stop

# %% [markdown]
# ### Separate Columns (Column left/right)

# %%
l = line_by_line(output)
for line in l:
    if line[1] < 500:
        print(line[0])
print("\nSecond Column")
for line in l:
    if line[1] >= 500:
        print(line[0])
# Out:
# 10martin
# de noel om w mit 10 martin de noel om w mit untut
# 12 united states patent
# stattin et al
# 54 random access procedure in
# wireless device
# and methods therein
# 71 applicant telefonaktiebolaget l m ericsson
# publ stockholm se
# 72 inventors magnus stattin upplands vsby se
# gunnar bergquist kista se tao
# cui upplands vsby se mats folke
# vllingby se gunnar mildh
# sollentuna se elena myhre jrflla
# se mikael wittberg uppsala se
# 73 assignee telefonaktiebolaget lm ericsson
# publ stockholm se
# * notice
# subject to any disclaimer the term of this
# patent is extended or adjusted under 35 gb
# u s c 154 b by 231 days
# 21 appl no
# 14 / 892 690
# 22 pct filed
# may 21 2014
# 86 pct no
# pct / se2014 / 050621
# $ 2 371 date
# c 1
# nov 20 2015
# 87 pct pub no w02014 / 189453
# pct pub date nov 27 2014
# 65
# prior publication data
# us 2016 / 0105912 a1 apr 14 2016
# related u s application data
# 60 provisional application no 61 / 825 593 filed on may
# 21 2013
# 51 int cl
# h04w 74 / 08
# h04l 12 / 24
#
# Second Column
# us010143012b2
# 10 patent no
# us 10 143 012 b2
# 45 date of patent
# nov 27 2018
# 52
# s ci
# radio base station
# cpc u
# h04w 74 / 0833 2013 01 h04l 41 / 0654
# 2013 01 h04w 74 / 08 2013 01
# 58 field of classification search
# none
# see application file for complete search history
# 56
# references cited
# u s patent documents
# 2009 / 0186624 al * 7 / 2009 cave
# ho4l 1 / 1887
# 455 / 450
# 2010 / 0202288 a1 * 8 / 2010 park
# h04w 48 / 08
# 370 / 230
# continued
# foreign patent documents
# 2461780 a
# 1 / 2010
# other publications
# unknown author " 3gpp ts 36 321 v11 2 0 mar 2013 " 3rd
# generation partnership project technical specification group radio
# access network evolved universal terrestrial radio access
# e - utra medium access control mac protocol specification
# release 11 mar 2013 pp 1 - 56
# continued
# primary examiner - george c atkins
# 74 attorney agent or firm  murphy bilak &
# homiller pllc
# 57
# abstract
# embodiments herein relate to a wireless device 10 for
# handling access to a radio base station 12 in a wireless
# communication network 1 the wireless device 10 being
# configured to
# initiate a random access procedure in the wireless com
# munication network 1
# determine that a problem with the random access proce
# dure has occurred when a certain condition is fulfilled
# 2009 01
# and
# 2006 01
# continued
# dr10 301 initiate ra procedure
# 302 select ra
# preamble
# 303 determine problem
# with ra procedure
# 304 perform an action
# 3041 delay
# 3042 abort

# %%
l
# Out:
# []

# %%
path = '/usr/local/google/home/fprost/Downloads/us_047.pdf'
client = vision.ImageAnnotatorClient()

with io.open(path, 'rb') as image_file:
    content = image_file.read()

image = vision.types.Image(content=content)

response = client.document_text_detection(image=image)
# Out:
# /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
image = 'gs://pdf-processing-219114/patents_test_fprost/valid_pdf/us_047.pdf'

batch_size = 1
mime_type = 'application/pdf'
client = vision.ImageAnnotatorClient()
feature = vision.types.Feature(
  type=vision.enums.Feature.Type.DOCUMENT_TEXT_DETECTION)
gcs_source = vision.types.GcsSource(uri=image)
input_config = vision.types.InputConfig(gcs_source=gcs_source,
                                        mime_type=mime_type)

gcs_destination = vision.types.GcsDestination(uri='gs://pdf-processing-219114/test_files/test.json')
output_config = vision.types.OutputConfig(
    gcs_destination=gcs_destination, batch_size=batch_size)

async_request = vision.types.AsyncAnnotateFileRequest(
  features=[feature],
  input_config=input_config,
  output_config=output_config)

operation = client.async_batch_annotate_files(requests=[async_request])
# todo(michaelsherman) catch and log the operation ID
response_mike = operation.result(timeout=150)
# Out:
# /usr/local/google/home/fprost/Documents/Projects/pdf_demo/datalab-notebooks/env_3.5/lib/python3.5/site-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
import tensorflow as tf
response_mike = tf.gfile.GFile('gs://pdf-processing-219114/test_files/test.jsonoutput-1-to-1.json', 'r')

# %%
response_mike = response_mike.read()

# %%
response_mike[:1000]
# Out:
# '{"inputConfig":{"gcsSource":{"uri":"gs://pdf-processing-219114/patents_test_fprost/valid_pdf/us_047.pdf"},"mimeType":"application/pdf"},"responses":[{"fullTextAnnotation":{"pages":[{"property":{"detectedLanguages":[{"languageCode":"en","confidence":0.79},{"languageCode":"sv","confidence":0.12},{"languageCode":"it","confidence":0.04},{"languageCode":"vi","confidence":0.01},{"languageCode":"gd","confidence":0.01}]},"width":612,"height":792,"blocks":[{"boundingBox":{"normalizedVertices":[{"x":0.62091506,"y":0.0479798},{"x":0.7352941,"y":0.0479798},{"x":0.7352941,"y":0.060606062},{"x":0.62091506,"y":0.060606062}]},"paragraphs":[{"boundingBox":{"normalizedVertices":[{"x":0.62091506,"y":0.0479798},{"x":0.7352941,"y":0.0479798},{"x":0.7352941,"y":0.060606062},{"x":0.62091506,"y":0.060606062}]},"words":[{"property":{"detectedLanguages":[{"languageCode":"en"}]},"boundingBox":{"normalizedVertices":[{"x":0.62091506,"y":0.0479798},{"x":0.7352941,"y":0.0479798},{"x":0.7352941,"y":0.060606062},{"x":'

# %%
response.text_annotations
# Out:
# [locale: "en"
# description: "10MARTIN\nDE NOEL OM W MIT UNTUT\nUS010143012B2\n(12) United States Patent\nStattin et al.\n(10) Patent No.: US 10,143,012 B2\n(45) Date of Patent: Nov. 27, 2018\n(54) RANDOM ACCESS PROCEDURE IN\nWIRELESS DEVICE, RADIO BASE STATION\nAND METHODS THEREIN\n(52) U.S. CI.\nCPC ..... H04W 74/0833 (2013.01); H04L 41/0654\n(2013.01); H04W 74/08 (2013.01)\n(58) Field of Classification Search\nNone\nSee application file for complete search history.\n(71)\nApplicant: Telefonaktiebolaget L M Ericsson\n(publ), Stockholm (SE)\n(56)\nReferences Cited\nU.S. PATENT DOCUMENTS\n(72) Inventors: Magnus Stattin, Upplands V\303\244sby (SE);\nGunnar Bergquist, Kista (SE); Tao\nCui, Upplands V\303\244sby (SE); Mats Folke,\nV\303\244llingby (SE); Gunnar Mildh,\nSollentuna (SE); Elena Myhre, J\303\244rf\303\244lla\n(SE); Mikael Wittberg, Uppsala (SE)\n2009/0186624 Al*\n7/2009 Cave ..........\n...\n2010/0202288 A1*\n8/2010 Park ........\nHO4L 1/1887\n455/450\nH04W 48/08\n370/230\n(73) Assignee: Telefonaktiebolaget LM Ericsson\n(publ), Stockholm (SE)\n(Continued)\nFOREIGN PATENT DOCUMENTS\n(*) Notice:\nSubject to any disclaimer, the term of this\npatent is extended or adjusted under 35\nU.S.C. 154(b) by 231 days.\nGB\n2461780 A\n1/2010\nOTHER PUBLICATIONS\n(21) Appl. No.:\n(22) PCT Filed:\n(86) PCT No.:\n$ 371 (c)(1),\n(2) Date:\n14/892,690\nMay 21, 2014\nPCT/SE2014/050621\nUnknown, Author, \"3GPP TS 36.321 V11.2.0 (Mar. 2013)\", 3rd\nGeneration Partnership Project; Technical Specification Group Radio\nAccess Network; Evolved Universal Terrestrial Radio Access\n(E-UTRA); Medium Access Control (MAC) protocol specification\n(Release 11), Mar. 2013, pp. 1-56.\n(Continued)\nNov. 20, 2015\n(87) PCT Pub. No.: W02014/189453\nPCT Pub. Date: Nov. 27, 2014\nPrimary Examiner - George C Atkins\n(74) Attorney, Agent, or Firm \342\200\224 Murphy, Bilak &\nHomiller, PLLC\n(65)\nPrior Publication Data\nUS 2016/0105912 A1 Apr. 14, 2016\nRelated U.S. Application Data\n(60) Provisional application No. 61/825,593, filed on May\n21, 2013\n(57)\nABSTRACT\nEmbodiments herein relate to a wireless device (10) for\nhandling access to a radio base station (12) in a wireless\ncommunication network (1), the wireless device (10) being\nconfigured to:\ninitiate a random access procedure in the wireless com-\nmunication network (1);\ndetermine that a problem with the random access proce-\ndure has occurred when a certain condition is fulfilled;\nand\n(Continued)\n(51)\nInt. Cl.\nH04W 74/08\nH04L 12/24\n(2009.01\n(2006.01)\nDr10\n301. Initiate RA procedure\n302. Select RA.\npreamble\n303. Determine problem\nwith RA procedure\n304. Perform an action\n3041. Delay\n3042. Abort\n3043. Stop\n"
# bounding_poly {
#   vertices {
#     x: 216
#     y: 44
#   }
#   vertices {
#     x: 1466
#     y: 44
#   }
#   vertices {
#     x: 1466
#     y: 2027
#   }
#   vertices {
#     x: 216
#     y: 2027
#   }
# }
# , description: "10"
# bounding_poly {
#   vertices {
#     x: 828
#     y: 44
#   }
#   vertices {
#     x: 852
#     y: 44
#   }
#   vertices {
#     x: 852
#     y: 108
#   }
#   vertices {
#     x: 828
#     y: 108
#   }
# }
# , description: "MARTIN"
# bounding_poly {
#   vertices {
#     x: 884
#     y: 44
#   }
#   vertices {
#     x: 966
#     y: 44
#   }
#   vertices {
#     x: 966
#     y: 108
#   }
#   vertices {
#     x: 884
#     y: 108
#   }
# }
# , description: "DE"
# bounding_poly {
#   vertices {
#     x: 950
#     y: 44
#   }
#   vertices {
#     x: 1067
#     y: 44
#   }
#   vertices {
#     x: 1067
#     y: 108
#   }
#   vertices {
#     x: 950
#     y: 108
#   }
# }
# , description: "NOEL"
# bounding_poly {
#   vertices {
#     x: 1057
#     y: 44
#   }
#   vertices {
#     x: 1135
#     y: 44
#   }
#   vertices {
#     x: 1135
#     y: 108
#   }
#   vertices {
#     x: 1057
#     y: 108
#   }
# }
# , description: "OM"
# bounding_poly {
#   vertices {
#     x: 1141
#     y: 44
#   }
#   vertices {
#     x: 1188
#     y: 44
#   }
#   vertices {
#     x: 1188
#     y: 108
#   }
#   vertices {
#     x: 1141
#     y: 108
#   }
# }
# , description: "W"
# bounding_poly {
#   vertices {
#     x: 1198
#     y: 44
#   }
#   vertices {
#     x: 1216
#     y: 44
#   }
#   vertices {
#     x: 1216
#     y: 108
#   }
#   vertices {
#     x: 1198
#     y: 108
#   }
# }
# , description: "MIT"
# bounding_poly {
#   vertices {
#     x: 1231
#     y: 44
#   }
#   vertices {
#     x: 1268
#     y: 44
#   }
#   vertices {
#     x: 1268
#     y: 108
#   }
#   vertices {
#     x: 1231
#     y: 108
#   }
# }
# , description: "UNTUT"
# bounding_poly {
#   vertices {
#     x: 1276
#     y: 44
#   }
#   vertices {
#     x: 1359
#     y: 44
#   }
#   vertices {
#     x: 1359
#     y: 108
#   }
#   vertices {
#     x: 1276
#     y: 108
#   }
# }
# , description: "US010143012B2"
# bounding_poly {
#   vertices {
#     x: 1055
#     y: 108
#   }
#   vertices {
#     x: 1251
#     y: 108
#   }
#   vertices {
#     x: 1251
#     y: 131
#   }
#   vertices {
#     x: 1055
#     y: 131
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 216
#     y: 190
#   }
#   vertices {
#     x: 228
#     y: 190
#   }
#   vertices {
#     x: 228
#     y: 234
#   }
#   vertices {
#     x: 216
#     y: 234
#   }
# }
# , description: "12"
# bounding_poly {
#   vertices {
#     x: 225
#     y: 190
#   }
#   vertices {
#     x: 249
#     y: 190
#   }
#   vertices {
#     x: 249
#     y: 234
#   }
#   vertices {
#     x: 225
#     y: 234
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 247
#     y: 190
#   }
#   vertices {
#     x: 259
#     y: 190
#   }
#   vertices {
#     x: 259
#     y: 234
#   }
#   vertices {
#     x: 247
#     y: 234
#   }
# }
# , description: "United"
# bounding_poly {
#   vertices {
#     x: 270
#     y: 190
#   }
#   vertices {
#     x: 404
#     y: 190
#   }
#   vertices {
#     x: 404
#     y: 234
#   }
#   vertices {
#     x: 270
#     y: 234
#   }
# }
# , description: "States"
# bounding_poly {
#   vertices {
#     x: 438
#     y: 190
#   }
#   vertices {
#     x: 559
#     y: 190
#   }
#   vertices {
#     x: 559
#     y: 234
#   }
#   vertices {
#     x: 438
#     y: 234
#   }
# }
# , description: "Patent"
# bounding_poly {
#   vertices {
#     x: 580
#     y: 190
#   }
#   vertices {
#     x: 719
#     y: 190
#   }
#   vertices {
#     x: 719
#     y: 234
#   }
#   vertices {
#     x: 580
#     y: 234
#   }
# }
# , description: "Stattin"
# bounding_poly {
#   vertices {
#     x: 274
#     y: 242
#   }
#   vertices {
#     x: 360
#     y: 242
#   }
#   vertices {
#     x: 360
#     y: 274
#   }
#   vertices {
#     x: 274
#     y: 274
#   }
# }
# , description: "et"
# bounding_poly {
#   vertices {
#     x: 380
#     y: 242
#   }
#   vertices {
#     x: 404
#     y: 242
#   }
#   vertices {
#     x: 404
#     y: 274
#   }
#   vertices {
#     x: 380
#     y: 274
#   }
# }
# , description: "al"
# bounding_poly {
#   vertices {
#     x: 416
#     y: 242
#   }
#   vertices {
#     x: 444
#     y: 242
#   }
#   vertices {
#     x: 444
#     y: 274
#   }
#   vertices {
#     x: 416
#     y: 274
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 441
#     y: 242
#   }
#   vertices {
#     x: 449
#     y: 242
#   }
#   vertices {
#     x: 449
#     y: 274
#   }
#   vertices {
#     x: 441
#     y: 274
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 899
#     y: 200
#   }
#   vertices {
#     x: 908
#     y: 200
#   }
#   vertices {
#     x: 908
#     y: 234
#   }
#   vertices {
#     x: 899
#     y: 234
#   }
# }
# , description: "10"
# bounding_poly {
#   vertices {
#     x: 910
#     y: 200
#   }
#   vertices {
#     x: 929
#     y: 200
#   }
#   vertices {
#     x: 929
#     y: 234
#   }
#   vertices {
#     x: 910
#     y: 234
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 934
#     y: 200
#   }
#   vertices {
#     x: 943
#     y: 200
#   }
#   vertices {
#     x: 943
#     y: 234
#   }
#   vertices {
#     x: 934
#     y: 234
#   }
# }
# , description: "Patent"
# bounding_poly {
#   vertices {
#     x: 957
#     y: 199
#   }
#   vertices {
#     x: 1047
#     y: 198
#   }
#   vertices {
#     x: 1047
#     y: 233
#   }
#   vertices {
#     x: 957
#     y: 234
#   }
# }
# , description: "No"
# bounding_poly {
#   vertices {
#     x: 1055
#     y: 199
#   }
#   vertices {
#     x: 1099
#     y: 199
#   }
#   vertices {
#     x: 1099
#     y: 233
#   }
#   vertices {
#     x: 1055
#     y: 233
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1099
#     y: 198
#   }
#   vertices {
#     x: 1108
#     y: 198
#   }
#   vertices {
#     x: 1108
#     y: 232
#   }
#   vertices {
#     x: 1099
#     y: 232
#   }
# }
# , description: ":"
# bounding_poly {
#   vertices {
#     x: 1109
#     y: 198
#   }
#   vertices {
#     x: 1118
#     y: 198
#   }
#   vertices {
#     x: 1118
#     y: 232
#   }
#   vertices {
#     x: 1109
#     y: 232
#   }
# }
# , description: "US"
# bounding_poly {
#   vertices {
#     x: 1169
#     y: 198
#   }
#   vertices {
#     x: 1219
#     y: 198
#   }
#   vertices {
#     x: 1219
#     y: 232
#   }
#   vertices {
#     x: 1169
#     y: 232
#   }
# }
# , description: "10"
# bounding_poly {
#   vertices {
#     x: 1237
#     y: 197
#   }
#   vertices {
#     x: 1268
#     y: 197
#   }
#   vertices {
#     x: 1268
#     y: 231
#   }
#   vertices {
#     x: 1237
#     y: 231
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 1270
#     y: 197
#   }
#   vertices {
#     x: 1279
#     y: 197
#   }
#   vertices {
#     x: 1279
#     y: 231
#   }
#   vertices {
#     x: 1270
#     y: 231
#   }
# }
# , description: "143"
# bounding_poly {
#   vertices {
#     x: 1286
#     y: 197
#   }
#   vertices {
#     x: 1339
#     y: 197
#   }
#   vertices {
#     x: 1339
#     y: 231
#   }
#   vertices {
#     x: 1286
#     y: 231
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 1340
#     y: 197
#   }
#   vertices {
#     x: 1349
#     y: 197
#   }
#   vertices {
#     x: 1349
#     y: 231
#   }
#   vertices {
#     x: 1340
#     y: 231
#   }
# }
# , description: "012"
# bounding_poly {
#   vertices {
#     x: 1350
#     y: 196
#   }
#   vertices {
#     x: 1404
#     y: 196
#   }
#   vertices {
#     x: 1404
#     y: 231
#   }
#   vertices {
#     x: 1350
#     y: 231
#   }
# }
# , description: "B2"
# bounding_poly {
#   vertices {
#     x: 1424
#     y: 196
#   }
#   vertices {
#     x: 1461
#     y: 196
#   }
#   vertices {
#     x: 1461
#     y: 230
#   }
#   vertices {
#     x: 1424
#     y: 230
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 898
#     y: 242
#   }
#   vertices {
#     x: 906
#     y: 242
#   }
#   vertices {
#     x: 906
#     y: 273
#   }
#   vertices {
#     x: 898
#     y: 273
#   }
# }
# , description: "45"
# bounding_poly {
#   vertices {
#     x: 906
#     y: 242
#   }
#   vertices {
#     x: 928
#     y: 242
#   }
#   vertices {
#     x: 928
#     y: 273
#   }
#   vertices {
#     x: 906
#     y: 273
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 933
#     y: 242
#   }
#   vertices {
#     x: 941
#     y: 242
#   }
#   vertices {
#     x: 941
#     y: 273
#   }
#   vertices {
#     x: 933
#     y: 273
#   }
# }
# , description: "Date"
# bounding_poly {
#   vertices {
#     x: 955
#     y: 242
#   }
#   vertices {
#     x: 1015
#     y: 242
#   }
#   vertices {
#     x: 1015
#     y: 273
#   }
#   vertices {
#     x: 955
#     y: 273
#   }
# }
# , description: "of"
# bounding_poly {
#   vertices {
#     x: 1030
#     y: 242
#   }
#   vertices {
#     x: 1058
#     y: 242
#   }
#   vertices {
#     x: 1058
#     y: 273
#   }
#   vertices {
#     x: 1030
#     y: 273
#   }
# }
# , description: "Patent"
# bounding_poly {
#   vertices {
#     x: 1070
#     y: 242
#   }
#   vertices {
#     x: 1161
#     y: 242
#   }
#   vertices {
#     x: 1161
#     y: 273
#   }
#   vertices {
#     x: 1070
#     y: 273
#   }
# }
# , description: ":"
# bounding_poly {
#   vertices {
#     x: 1163
#     y: 242
#   }
#   vertices {
#     x: 1171
#     y: 242
#   }
#   vertices {
#     x: 1171
#     y: 273
#   }
#   vertices {
#     x: 1163
#     y: 273
#   }
# }
# , description: "Nov"
# bounding_poly {
#   vertices {
#     x: 1267
#     y: 242
#   }
#   vertices {
#     x: 1321
#     y: 242
#   }
#   vertices {
#     x: 1321
#     y: 273
#   }
#   vertices {
#     x: 1267
#     y: 273
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1327
#     y: 242
#   }
#   vertices {
#     x: 1335
#     y: 242
#   }
#   vertices {
#     x: 1335
#     y: 273
#   }
#   vertices {
#     x: 1327
#     y: 273
#   }
# }
# , description: "27"
# bounding_poly {
#   vertices {
#     x: 1344
#     y: 242
#   }
#   vertices {
#     x: 1372
#     y: 242
#   }
#   vertices {
#     x: 1372
#     y: 273
#   }
#   vertices {
#     x: 1344
#     y: 273
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 1375
#     y: 242
#   }
#   vertices {
#     x: 1383
#     y: 242
#   }
#   vertices {
#     x: 1383
#     y: 273
#   }
#   vertices {
#     x: 1375
#     y: 273
#   }
# }
# , description: "2018"
# bounding_poly {
#   vertices {
#     x: 1396
#     y: 242
#   }
#   vertices {
#     x: 1454
#     y: 242
#   }
#   vertices {
#     x: 1454
#     y: 273
#   }
#   vertices {
#     x: 1396
#     y: 273
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 217
#     y: 331
#   }
#   vertices {
#     x: 223
#     y: 331
#   }
#   vertices {
#     x: 223
#     y: 355
#   }
#   vertices {
#     x: 217
#     y: 355
#   }
# }
# , description: "54"
# bounding_poly {
#   vertices {
#     x: 225
#     y: 331
#   }
#   vertices {
#     x: 247
#     y: 331
#   }
#   vertices {
#     x: 247
#     y: 355
#   }
#   vertices {
#     x: 225
#     y: 355
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 249
#     y: 331
#   }
#   vertices {
#     x: 255
#     y: 331
#   }
#   vertices {
#     x: 255
#     y: 355
#   }
#   vertices {
#     x: 249
#     y: 355
#   }
# }
# , description: "RANDOM"
# bounding_poly {
#   vertices {
#     x: 283
#     y: 331
#   }
#   vertices {
#     x: 388
#     y: 331
#   }
#   vertices {
#     x: 388
#     y: 355
#   }
#   vertices {
#     x: 283
#     y: 355
#   }
# }
# , description: "ACCESS"
# bounding_poly {
#   vertices {
#     x: 406
#     y: 331
#   }
#   vertices {
#     x: 500
#     y: 331
#   }
#   vertices {
#     x: 500
#     y: 355
#   }
#   vertices {
#     x: 406
#     y: 355
#   }
# }
# , description: "PROCEDURE"
# bounding_poly {
#   vertices {
#     x: 512
#     y: 331
#   }
#   vertices {
#     x: 668
#     y: 331
#   }
#   vertices {
#     x: 668
#     y: 355
#   }
#   vertices {
#     x: 512
#     y: 355
#   }
# }
# , description: "IN"
# bounding_poly {
#   vertices {
#     x: 682
#     y: 331
#   }
#   vertices {
#     x: 695
#     y: 331
#   }
#   vertices {
#     x: 695
#     y: 355
#   }
#   vertices {
#     x: 682
#     y: 355
#   }
# }
# , description: "WIRELESS"
# bounding_poly {
#   vertices {
#     x: 278
#     y: 360
#   }
#   vertices {
#     x: 410
#     y: 360
#   }
#   vertices {
#     x: 410
#     y: 385
#   }
#   vertices {
#     x: 278
#     y: 385
#   }
# }
# , description: "DEVICE"
# bounding_poly {
#   vertices {
#     x: 421
#     y: 360
#   }
#   vertices {
#     x: 512
#     y: 360
#   }
#   vertices {
#     x: 512
#     y: 385
#   }
#   vertices {
#     x: 421
#     y: 385
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 518
#     y: 360
#   }
#   vertices {
#     x: 524
#     y: 360
#   }
#   vertices {
#     x: 524
#     y: 385
#   }
#   vertices {
#     x: 518
#     y: 385
#   }
# }
# , description: "RADIO"
# bounding_poly {
#   vertices {
#     x: 533
#     y: 360
#   }
#   vertices {
#     x: 607
#     y: 360
#   }
#   vertices {
#     x: 607
#     y: 385
#   }
#   vertices {
#     x: 533
#     y: 385
#   }
# }
# , description: "BASE"
# bounding_poly {
#   vertices {
#     x: 626
#     y: 360
#   }
#   vertices {
#     x: 683
#     y: 360
#   }
#   vertices {
#     x: 683
#     y: 385
#   }
#   vertices {
#     x: 626
#     y: 385
#   }
# }
# , description: "STATION"
# bounding_poly {
#   vertices {
#     x: 698
#     y: 360
#   }
#   vertices {
#     x: 799
#     y: 360
#   }
#   vertices {
#     x: 799
#     y: 385
#   }
#   vertices {
#     x: 698
#     y: 385
#   }
# }
# , description: "AND"
# bounding_poly {
#   vertices {
#     x: 283
#     y: 390
#   }
#   vertices {
#     x: 331
#     y: 390
#   }
#   vertices {
#     x: 331
#     y: 411
#   }
#   vertices {
#     x: 283
#     y: 411
#   }
# }
# , description: "METHODS"
# bounding_poly {
#   vertices {
#     x: 341
#     y: 390
#   }
#   vertices {
#     x: 468
#     y: 390
#   }
#   vertices {
#     x: 468
#     y: 411
#   }
#   vertices {
#     x: 341
#     y: 411
#   }
# }
# , description: "THEREIN"
# bounding_poly {
#   vertices {
#     x: 483
#     y: 390
#   }
#   vertices {
#     x: 585
#     y: 390
#   }
#   vertices {
#     x: 585
#     y: 411
#   }
#   vertices {
#     x: 483
#     y: 411
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 866
#     y: 326
#   }
#   vertices {
#     x: 875
#     y: 326
#   }
#   vertices {
#     x: 876
#     y: 361
#   }
#   vertices {
#     x: 867
#     y: 361
#   }
# }
# , description: "52"
# bounding_poly {
#   vertices {
#     x: 872
#     y: 325
#   }
#   vertices {
#     x: 898
#     y: 324
#   }
#   vertices {
#     x: 899
#     y: 359
#   }
#   vertices {
#     x: 873
#     y: 360
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 898
#     y: 325
#   }
#   vertices {
#     x: 907
#     y: 325
#   }
#   vertices {
#     x: 908
#     y: 360
#   }
#   vertices {
#     x: 899
#     y: 360
#   }
# }
# , description: "U"
# bounding_poly {
#   vertices {
#     x: 934
#     y: 324
#   }
#   vertices {
#     x: 943
#     y: 324
#   }
#   vertices {
#     x: 944
#     y: 359
#   }
#   vertices {
#     x: 935
#     y: 359
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 949
#     y: 323
#   }
#   vertices {
#     x: 958
#     y: 323
#   }
#   vertices {
#     x: 959
#     y: 358
#   }
#   vertices {
#     x: 950
#     y: 358
#   }
# }
# , description: "S"
# bounding_poly {
#   vertices {
#     x: 956
#     y: 323
#   }
#   vertices {
#     x: 965
#     y: 323
#   }
#   vertices {
#     x: 966
#     y: 358
#   }
#   vertices {
#     x: 957
#     y: 358
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 970
#     y: 323
#   }
#   vertices {
#     x: 979
#     y: 323
#   }
#   vertices {
#     x: 980
#     y: 358
#   }
#   vertices {
#     x: 971
#     y: 358
#   }
# }
# , description: "CI"
# bounding_poly {
#   vertices {
#     x: 987
#     y: 322
#   }
#   vertices {
#     x: 1013
#     y: 321
#   }
#   vertices {
#     x: 1014
#     y: 356
#   }
#   vertices {
#     x: 988
#     y: 357
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1010
#     y: 322
#   }
#   vertices {
#     x: 1019
#     y: 322
#   }
#   vertices {
#     x: 1020
#     y: 357
#   }
#   vertices {
#     x: 1011
#     y: 357
#   }
# }
# , description: "CPC"
# bounding_poly {
#   vertices {
#     x: 932
#     y: 358
#   }
#   vertices {
#     x: 970
#     y: 358
#   }
#   vertices {
#     x: 970
#     y: 380
#   }
#   vertices {
#     x: 932
#     y: 380
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 991
#     y: 358
#   }
#   vertices {
#     x: 996
#     y: 358
#   }
#   vertices {
#     x: 996
#     y: 380
#   }
#   vertices {
#     x: 991
#     y: 380
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 996
#     y: 358
#   }
#   vertices {
#     x: 1001
#     y: 358
#   }
#   vertices {
#     x: 1001
#     y: 380
#   }
#   vertices {
#     x: 996
#     y: 380
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1003
#     y: 358
#   }
#   vertices {
#     x: 1008
#     y: 358
#   }
#   vertices {
#     x: 1008
#     y: 380
#   }
#   vertices {
#     x: 1003
#     y: 380
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1009
#     y: 358
#   }
#   vertices {
#     x: 1014
#     y: 358
#   }
#   vertices {
#     x: 1014
#     y: 380
#   }
#   vertices {
#     x: 1009
#     y: 380
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1014
#     y: 358
#   }
#   vertices {
#     x: 1019
#     y: 358
#   }
#   vertices {
#     x: 1019
#     y: 380
#   }
#   vertices {
#     x: 1014
#     y: 380
#   }
# }
# , description: "H04W"
# bounding_poly {
#   vertices {
#     x: 1037
#     y: 358
#   }
#   vertices {
#     x: 1093
#     y: 358
#   }
#   vertices {
#     x: 1093
#     y: 380
#   }
#   vertices {
#     x: 1037
#     y: 380
#   }
# }
# , description: "74"
# bounding_poly {
#   vertices {
#     x: 1113
#     y: 358
#   }
#   vertices {
#     x: 1134
#     y: 358
#   }
#   vertices {
#     x: 1134
#     y: 380
#   }
#   vertices {
#     x: 1113
#     y: 380
#   }
# }
# , description: "/"
# bounding_poly {
#   vertices {
#     x: 1138
#     y: 358
#   }
#   vertices {
#     x: 1143
#     y: 358
#   }
#   vertices {
#     x: 1143
#     y: 380
#   }
#   vertices {
#     x: 1138
#     y: 380
#   }
# }
# , description: "0833"
# bounding_poly {
#   vertices {
#     x: 1142
#     y: 358
#   }
#   vertices {
#     x: 1190
#     y: 358
#   }
#   vertices {
#     x: 1190
#     y: 380
#   }
#   vertices {
#     x: 1142
#     y: 380
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 1205
#     y: 358
#   }
#   vertices {
#     x: 1210
#     y: 358
#   }
#   vertices {
#     x: 1210
#     y: 380
#   }
#   vertices {
#     x: 1205
#     y: 380
#   }
# }
# , description: "2013"
# bounding_poly {
#   vertices {
#     x: 1210
#     y: 358
#   }
#   vertices {
#     x: 1257
#     y: 358
#   }
#   vertices {
#     x: 1257
#     y: 380
#   }
#   vertices {
#     x: 1210
#     y: 380
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1260
#     y: 358
#   }
#   vertices {
#     x: 1265
#     y: 358
#   }
#   vertices {
#     x: 1265
#     y: 380
#   }
#   vertices {
#     x: 1260
#     y: 380
#   }
# }
# , description: "01"
# bounding_poly {
#   vertices {
#     x: 1266
#     y: 358
#   }
#   vertices {
#     x: 1290
#     y: 358
#   }
#   vertices {
#     x: 1290
#     y: 380
#   }
#   vertices {
#     x: 1266
#     y: 380
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 1292
#     y: 358
#   }
#   vertices {
#     x: 1297
#     y: 358
#   }
#   vertices {
#     x: 1297
#     y: 380
#   }
#   vertices {
#     x: 1292
#     y: 380
#   }
# }
# , description: ";"
# bounding_poly {
#   vertices {
#     x: 1301
#     y: 358
#   }
#   vertices {
#     x: 1306
#     y: 358
#   }
#   vertices {
#     x: 1306
#     y: 380
#   }
#   vertices {
#     x: 1301
#     y: 380
#   }
# }
# , description: "H04L"
# bounding_poly {
#   vertices {
#     x: 1316
#     y: 358
#   }
#   vertices {
#     x: 1372
#     y: 358
#   }
#   vertices {
#     x: 1372
#     y: 380
#   }
#   vertices {
#     x: 1316
#     y: 380
#   }
# }
# , description: "41"
# bounding_poly {
#   vertices {
#     x: 1381
#     y: 358
#   }
#   vertices {
#     x: 1409
#     y: 358
#   }
#   vertices {
#     x: 1409
#     y: 380
#   }
#   vertices {
#     x: 1381
#     y: 380
#   }
# }
# , description: "/"
# bounding_poly {
#   vertices {
#     x: 1407
#     y: 358
#   }
#   vertices {
#     x: 1412
#     y: 358
#   }
#   vertices {
#     x: 1412
#     y: 380
#   }
#   vertices {
#     x: 1407
#     y: 380
#   }
# }
# , description: "0654"
# bounding_poly {
#   vertices {
#     x: 1415
#     y: 358
#   }
#   vertices {
#     x: 1460
#     y: 358
#   }
#   vertices {
#     x: 1460
#     y: 380
#   }
#   vertices {
#     x: 1415
#     y: 380
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 1117
#     y: 386
#   }
#   vertices {
#     x: 1122
#     y: 386
#   }
#   vertices {
#     x: 1122
#     y: 407
#   }
#   vertices {
#     x: 1117
#     y: 407
#   }
# }
# , description: "2013"
# bounding_poly {
#   vertices {
#     x: 1122
#     y: 386
#   }
#   vertices {
#     x: 1167
#     y: 386
#   }
#   vertices {
#     x: 1167
#     y: 407
#   }
#   vertices {
#     x: 1122
#     y: 407
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1172
#     y: 386
#   }
#   vertices {
#     x: 1177
#     y: 386
#   }
#   vertices {
#     x: 1177
#     y: 407
#   }
#   vertices {
#     x: 1172
#     y: 407
#   }
# }
# , description: "01"
# bounding_poly {
#   vertices {
#     x: 1178
#     y: 386
#   }
#   vertices {
#     x: 1201
#     y: 386
#   }
#   vertices {
#     x: 1201
#     y: 407
#   }
#   vertices {
#     x: 1178
#     y: 407
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 1203
#     y: 386
#   }
#   vertices {
#     x: 1208
#     y: 386
#   }
#   vertices {
#     x: 1208
#     y: 407
#   }
#   vertices {
#     x: 1203
#     y: 407
#   }
# }
# , description: ";"
# bounding_poly {
#   vertices {
#     x: 1212
#     y: 386
#   }
#   vertices {
#     x: 1217
#     y: 386
#   }
#   vertices {
#     x: 1217
#     y: 407
#   }
#   vertices {
#     x: 1212
#     y: 407
#   }
# }
# , description: "H04W"
# bounding_poly {
#   vertices {
#     x: 1229
#     y: 386
#   }
#   vertices {
#     x: 1284
#     y: 386
#   }
#   vertices {
#     x: 1284
#     y: 407
#   }
#   vertices {
#     x: 1229
#     y: 407
#   }
# }
# , description: "74"
# bounding_poly {
#   vertices {
#     x: 1302
#     y: 386
#   }
#   vertices {
#     x: 1321
#     y: 386
#   }
#   vertices {
#     x: 1321
#     y: 407
#   }
#   vertices {
#     x: 1302
#     y: 407
#   }
# }
# , description: "/"
# bounding_poly {
#   vertices {
#     x: 1326
#     y: 386
#   }
#   vertices {
#     x: 1331
#     y: 386
#   }
#   vertices {
#     x: 1331
#     y: 407
#   }
#   vertices {
#     x: 1326
#     y: 407
#   }
# }
# , description: "08"
# bounding_poly {
#   vertices {
#     x: 1333
#     y: 386
#   }
#   vertices {
#     x: 1352
#     y: 386
#   }
#   vertices {
#     x: 1352
#     y: 407
#   }
#   vertices {
#     x: 1333
#     y: 407
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 1368
#     y: 386
#   }
#   vertices {
#     x: 1373
#     y: 386
#   }
#   vertices {
#     x: 1373
#     y: 407
#   }
#   vertices {
#     x: 1368
#     y: 407
#   }
# }
# , description: "2013"
# bounding_poly {
#   vertices {
#     x: 1375
#     y: 386
#   }
#   vertices {
#     x: 1420
#     y: 386
#   }
#   vertices {
#     x: 1420
#     y: 407
#   }
#   vertices {
#     x: 1375
#     y: 407
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1425
#     y: 386
#   }
#   vertices {
#     x: 1430
#     y: 386
#   }
#   vertices {
#     x: 1430
#     y: 407
#   }
#   vertices {
#     x: 1425
#     y: 407
#   }
# }
# , description: "01"
# bounding_poly {
#   vertices {
#     x: 1429
#     y: 386
#   }
#   vertices {
#     x: 1455
#     y: 386
#   }
#   vertices {
#     x: 1455
#     y: 407
#   }
#   vertices {
#     x: 1429
#     y: 407
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 1456
#     y: 386
#   }
#   vertices {
#     x: 1461
#     y: 386
#   }
#   vertices {
#     x: 1461
#     y: 407
#   }
#   vertices {
#     x: 1456
#     y: 407
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 867
#     y: 411
#   }
#   vertices {
#     x: 875
#     y: 411
#   }
#   vertices {
#     x: 875
#     y: 440
#   }
#   vertices {
#     x: 867
#     y: 440
#   }
# }
# , description: "58"
# bounding_poly {
#   vertices {
#     x: 872
#     y: 411
#   }
#   vertices {
#     x: 893
#     y: 411
#   }
#   vertices {
#     x: 893
#     y: 440
#   }
#   vertices {
#     x: 872
#     y: 440
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 900
#     y: 411
#   }
#   vertices {
#     x: 908
#     y: 411
#   }
#   vertices {
#     x: 908
#     y: 440
#   }
#   vertices {
#     x: 900
#     y: 440
#   }
# }
# , description: "Field"
# bounding_poly {
#   vertices {
#     x: 935
#     y: 411
#   }
#   vertices {
#     x: 978
#     y: 411
#   }
#   vertices {
#     x: 978
#     y: 440
#   }
#   vertices {
#     x: 935
#     y: 440
#   }
# }
# , description: "of"
# bounding_poly {
#   vertices {
#     x: 995
#     y: 411
#   }
#   vertices {
#     x: 1016
#     y: 411
#   }
#   vertices {
#     x: 1016
#     y: 440
#   }
#   vertices {
#     x: 995
#     y: 440
#   }
# }
# , description: "Classification"
# bounding_poly {
#   vertices {
#     x: 1024
#     y: 411
#   }
#   vertices {
#     x: 1159
#     y: 411
#   }
#   vertices {
#     x: 1159
#     y: 440
#   }
#   vertices {
#     x: 1024
#     y: 440
#   }
# }
# , description: "Search"
# bounding_poly {
#   vertices {
#     x: 1175
#     y: 411
#   }
#   vertices {
#     x: 1240
#     y: 411
#   }
#   vertices {
#     x: 1240
#     y: 440
#   }
#   vertices {
#     x: 1175
#     y: 440
#   }
# }
# , description: "None"
# bounding_poly {
#   vertices {
#     x: 930
#     y: 440
#   }
#   vertices {
#     x: 984
#     y: 440
#   }
#   vertices {
#     x: 984
#     y: 462
#   }
#   vertices {
#     x: 930
#     y: 462
#   }
# }
# , description: "See"
# bounding_poly {
#   vertices {
#     x: 933
#     y: 468
#   }
#   vertices {
#     x: 963
#     y: 468
#   }
#   vertices {
#     x: 963
#     y: 491
#   }
#   vertices {
#     x: 933
#     y: 491
#   }
# }
# , description: "application"
# bounding_poly {
#   vertices {
#     x: 977
#     y: 468
#   }
#   vertices {
#     x: 1085
#     y: 468
#   }
#   vertices {
#     x: 1085
#     y: 491
#   }
#   vertices {
#     x: 977
#     y: 491
#   }
# }
# , description: "file"
# bounding_poly {
#   vertices {
#     x: 1096
#     y: 468
#   }
#   vertices {
#     x: 1122
#     y: 468
#   }
#   vertices {
#     x: 1122
#     y: 491
#   }
#   vertices {
#     x: 1096
#     y: 491
#   }
# }
# , description: "for"
# bounding_poly {
#   vertices {
#     x: 1136
#     y: 468
#   }
#   vertices {
#     x: 1162
#     y: 468
#   }
#   vertices {
#     x: 1162
#     y: 491
#   }
#   vertices {
#     x: 1136
#     y: 491
#   }
# }
# , description: "complete"
# bounding_poly {
#   vertices {
#     x: 1174
#     y: 468
#   }
#   vertices {
#     x: 1260
#     y: 468
#   }
#   vertices {
#     x: 1260
#     y: 491
#   }
#   vertices {
#     x: 1174
#     y: 491
#   }
# }
# , description: "search"
# bounding_poly {
#   vertices {
#     x: 1272
#     y: 468
#   }
#   vertices {
#     x: 1330
#     y: 468
#   }
#   vertices {
#     x: 1330
#     y: 491
#   }
#   vertices {
#     x: 1272
#     y: 491
#   }
# }
# , description: "history"
# bounding_poly {
#   vertices {
#     x: 1343
#     y: 468
#   }
#   vertices {
#     x: 1409
#     y: 468
#   }
#   vertices {
#     x: 1409
#     y: 491
#   }
#   vertices {
#     x: 1343
#     y: 491
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1412
#     y: 468
#   }
#   vertices {
#     x: 1418
#     y: 468
#   }
#   vertices {
#     x: 1418
#     y: 491
#   }
#   vertices {
#     x: 1412
#     y: 491
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 217
#     y: 441
#   }
#   vertices {
#     x: 224
#     y: 441
#   }
#   vertices {
#     x: 224
#     y: 467
#   }
#   vertices {
#     x: 217
#     y: 467
#   }
# }
# , description: "71"
# bounding_poly {
#   vertices {
#     x: 224
#     y: 441
#   }
#   vertices {
#     x: 247
#     y: 441
#   }
#   vertices {
#     x: 247
#     y: 467
#   }
#   vertices {
#     x: 224
#     y: 467
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 249
#     y: 441
#   }
#   vertices {
#     x: 256
#     y: 441
#   }
#   vertices {
#     x: 256
#     y: 467
#   }
#   vertices {
#     x: 249
#     y: 467
#   }
# }
# , description: "Applicant"
# bounding_poly {
#   vertices {
#     x: 286
#     y: 441
#   }
#   vertices {
#     x: 381
#     y: 441
#   }
#   vertices {
#     x: 381
#     y: 467
#   }
#   vertices {
#     x: 286
#     y: 467
#   }
# }
# , description: ":"
# bounding_poly {
#   vertices {
#     x: 382
#     y: 441
#   }
#   vertices {
#     x: 389
#     y: 441
#   }
#   vertices {
#     x: 389
#     y: 467
#   }
#   vertices {
#     x: 382
#     y: 467
#   }
# }
# , description: "Telefonaktiebolaget"
# bounding_poly {
#   vertices {
#     x: 407
#     y: 441
#   }
#   vertices {
#     x: 608
#     y: 441
#   }
#   vertices {
#     x: 608
#     y: 467
#   }
#   vertices {
#     x: 407
#     y: 467
#   }
# }
# , description: "L"
# bounding_poly {
#   vertices {
#     x: 619
#     y: 441
#   }
#   vertices {
#     x: 626
#     y: 441
#   }
#   vertices {
#     x: 626
#     y: 467
#   }
#   vertices {
#     x: 619
#     y: 467
#   }
# }
# , description: "M"
# bounding_poly {
#   vertices {
#     x: 641
#     y: 441
#   }
#   vertices {
#     x: 648
#     y: 441
#   }
#   vertices {
#     x: 648
#     y: 467
#   }
#   vertices {
#     x: 641
#     y: 467
#   }
# }
# , description: "Ericsson"
# bounding_poly {
#   vertices {
#     x: 675
#     y: 441
#   }
#   vertices {
#     x: 756
#     y: 441
#   }
#   vertices {
#     x: 756
#     y: 467
#   }
#   vertices {
#     x: 675
#     y: 467
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 400
#     y: 470
#   }
#   vertices {
#     x: 406
#     y: 470
#   }
#   vertices {
#     x: 406
#     y: 493
#   }
#   vertices {
#     x: 400
#     y: 493
#   }
# }
# , description: "publ"
# bounding_poly {
#   vertices {
#     x: 409
#     y: 470
#   }
#   vertices {
#     x: 456
#     y: 470
#   }
#   vertices {
#     x: 456
#     y: 493
#   }
#   vertices {
#     x: 409
#     y: 493
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 456
#     y: 470
#   }
#   vertices {
#     x: 462
#     y: 470
#   }
#   vertices {
#     x: 462
#     y: 493
#   }
#   vertices {
#     x: 456
#     y: 493
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 463
#     y: 470
#   }
#   vertices {
#     x: 469
#     y: 470
#   }
#   vertices {
#     x: 469
#     y: 493
#   }
#   vertices {
#     x: 463
#     y: 493
#   }
# }
# , description: "Stockholm"
# bounding_poly {
#   vertices {
#     x: 481
#     y: 470
#   }
#   vertices {
#     x: 574
#     y: 470
#   }
#   vertices {
#     x: 574
#     y: 493
#   }
#   vertices {
#     x: 481
#     y: 493
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 597
#     y: 470
#   }
#   vertices {
#     x: 603
#     y: 470
#   }
#   vertices {
#     x: 603
#     y: 493
#   }
#   vertices {
#     x: 597
#     y: 493
#   }
# }
# , description: "SE"
# bounding_poly {
#   vertices {
#     x: 602
#     y: 470
#   }
#   vertices {
#     x: 628
#     y: 470
#   }
#   vertices {
#     x: 628
#     y: 493
#   }
#   vertices {
#     x: 602
#     y: 493
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 633
#     y: 470
#   }
#   vertices {
#     x: 639
#     y: 470
#   }
#   vertices {
#     x: 639
#     y: 493
#   }
#   vertices {
#     x: 633
#     y: 493
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 866
#     y: 523
#   }
#   vertices {
#     x: 871
#     y: 523
#   }
#   vertices {
#     x: 871
#     y: 544
#   }
#   vertices {
#     x: 866
#     y: 544
#   }
# }
# , description: "56"
# bounding_poly {
#   vertices {
#     x: 873
#     y: 523
#   }
#   vertices {
#     x: 892
#     y: 523
#   }
#   vertices {
#     x: 892
#     y: 544
#   }
#   vertices {
#     x: 873
#     y: 544
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 899
#     y: 523
#   }
#   vertices {
#     x: 904
#     y: 523
#   }
#   vertices {
#     x: 904
#     y: 544
#   }
#   vertices {
#     x: 899
#     y: 544
#   }
# }
# , description: "References"
# bounding_poly {
#   vertices {
#     x: 1072
#     y: 520
#   }
#   vertices {
#     x: 1186
#     y: 520
#   }
#   vertices {
#     x: 1186
#     y: 543
#   }
#   vertices {
#     x: 1072
#     y: 543
#   }
# }
# , description: "Cited"
# bounding_poly {
#   vertices {
#     x: 1197
#     y: 520
#   }
#   vertices {
#     x: 1251
#     y: 520
#   }
#   vertices {
#     x: 1251
#     y: 543
#   }
#   vertices {
#     x: 1197
#     y: 543
#   }
# }
# , description: "U"
# bounding_poly {
#   vertices {
#     x: 1012
#     y: 565
#   }
#   vertices {
#     x: 1019
#     y: 565
#   }
#   vertices {
#     x: 1019
#     y: 592
#   }
#   vertices {
#     x: 1012
#     y: 592
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1029
#     y: 565
#   }
#   vertices {
#     x: 1036
#     y: 565
#   }
#   vertices {
#     x: 1036
#     y: 592
#   }
#   vertices {
#     x: 1029
#     y: 592
#   }
# }
# , description: "S"
# bounding_poly {
#   vertices {
#     x: 1037
#     y: 565
#   }
#   vertices {
#     x: 1044
#     y: 565
#   }
#   vertices {
#     x: 1044
#     y: 592
#   }
#   vertices {
#     x: 1037
#     y: 592
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1049
#     y: 565
#   }
#   vertices {
#     x: 1056
#     y: 565
#   }
#   vertices {
#     x: 1056
#     y: 592
#   }
#   vertices {
#     x: 1049
#     y: 592
#   }
# }
# , description: "PATENT"
# bounding_poly {
#   vertices {
#     x: 1063
#     y: 565
#   }
#   vertices {
#     x: 1157
#     y: 565
#   }
#   vertices {
#     x: 1157
#     y: 592
#   }
#   vertices {
#     x: 1063
#     y: 592
#   }
# }
# , description: "DOCUMENTS"
# bounding_poly {
#   vertices {
#     x: 1163
#     y: 565
#   }
#   vertices {
#     x: 1315
#     y: 565
#   }
#   vertices {
#     x: 1315
#     y: 592
#   }
#   vertices {
#     x: 1163
#     y: 592
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 218
#     y: 523
#   }
#   vertices {
#     x: 224
#     y: 523
#   }
#   vertices {
#     x: 224
#     y: 546
#   }
#   vertices {
#     x: 218
#     y: 546
#   }
# }
# , description: "72"
# bounding_poly {
#   vertices {
#     x: 224
#     y: 523
#   }
#   vertices {
#     x: 245
#     y: 523
#   }
#   vertices {
#     x: 245
#     y: 546
#   }
#   vertices {
#     x: 224
#     y: 546
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 250
#     y: 523
#   }
#   vertices {
#     x: 256
#     y: 523
#   }
#   vertices {
#     x: 256
#     y: 546
#   }
#   vertices {
#     x: 250
#     y: 546
#   }
# }
# , description: "Inventors"
# bounding_poly {
#   vertices {
#     x: 284
#     y: 523
#   }
#   vertices {
#     x: 374
#     y: 523
#   }
#   vertices {
#     x: 374
#     y: 546
#   }
#   vertices {
#     x: 284
#     y: 546
#   }
# }
# , description: ":"
# bounding_poly {
#   vertices {
#     x: 377
#     y: 523
#   }
#   vertices {
#     x: 383
#     y: 523
#   }
#   vertices {
#     x: 383
#     y: 546
#   }
#   vertices {
#     x: 377
#     y: 546
#   }
# }
# , description: "Magnus"
# bounding_poly {
#   vertices {
#     x: 394
#     y: 523
#   }
#   vertices {
#     x: 483
#     y: 523
#   }
#   vertices {
#     x: 483
#     y: 546
#   }
#   vertices {
#     x: 394
#     y: 546
#   }
# }
# , description: "Stattin"
# bounding_poly {
#   vertices {
#     x: 495
#     y: 523
#   }
#   vertices {
#     x: 558
#     y: 523
#   }
#   vertices {
#     x: 558
#     y: 546
#   }
#   vertices {
#     x: 495
#     y: 546
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 564
#     y: 523
#   }
#   vertices {
#     x: 570
#     y: 523
#   }
#   vertices {
#     x: 570
#     y: 546
#   }
#   vertices {
#     x: 564
#     y: 546
#   }
# }
# , description: "Upplands"
# bounding_poly {
#   vertices {
#     x: 576
#     y: 523
#   }
#   vertices {
#     x: 675
#     y: 523
#   }
#   vertices {
#     x: 675
#     y: 546
#   }
#   vertices {
#     x: 576
#     y: 546
#   }
# }
# , description: "V\303\244sby"
# bounding_poly {
#   vertices {
#     x: 688
#     y: 523
#   }
#   vertices {
#     x: 742
#     y: 523
#   }
#   vertices {
#     x: 742
#     y: 546
#   }
#   vertices {
#     x: 688
#     y: 546
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 754
#     y: 523
#   }
#   vertices {
#     x: 760
#     y: 523
#   }
#   vertices {
#     x: 760
#     y: 546
#   }
#   vertices {
#     x: 754
#     y: 546
#   }
# }
# , description: "SE"
# bounding_poly {
#   vertices {
#     x: 761
#     y: 523
#   }
#   vertices {
#     x: 787
#     y: 523
#   }
#   vertices {
#     x: 787
#     y: 546
#   }
#   vertices {
#     x: 761
#     y: 546
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 790
#     y: 523
#   }
#   vertices {
#     x: 796
#     y: 523
#   }
#   vertices {
#     x: 796
#     y: 546
#   }
#   vertices {
#     x: 790
#     y: 546
#   }
# }
# , description: ";"
# bounding_poly {
#   vertices {
#     x: 799
#     y: 523
#   }
#   vertices {
#     x: 805
#     y: 523
#   }
#   vertices {
#     x: 805
#     y: 546
#   }
#   vertices {
#     x: 799
#     y: 546
#   }
# }
# , description: "Gunnar"
# bounding_poly {
#   vertices {
#     x: 396
#     y: 551
#   }
#   vertices {
#     x: 481
#     y: 551
#   }
#   vertices {
#     x: 481
#     y: 575
#   }
#   vertices {
#     x: 396
#     y: 575
#   }
# }
# , description: "Bergquist"
# bounding_poly {
#   vertices {
#     x: 493
#     y: 551
#   }
#   vertices {
#     x: 595
#     y: 551
#   }
#   vertices {
#     x: 595
#     y: 575
#   }
#   vertices {
#     x: 493
#     y: 575
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 596
#     y: 551
#   }
#   vertices {
#     x: 602
#     y: 551
#   }
#   vertices {
#     x: 602
#     y: 575
#   }
#   vertices {
#     x: 596
#     y: 575
#   }
# }
# , description: "Kista"
# bounding_poly {
#   vertices {
#     x: 611
#     y: 551
#   }
#   vertices {
#     x: 659
#     y: 551
#   }
#   vertices {
#     x: 659
#     y: 575
#   }
#   vertices {
#     x: 611
#     y: 575
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 673
#     y: 551
#   }
#   vertices {
#     x: 679
#     y: 551
#   }
#   vertices {
#     x: 679
#     y: 575
#   }
#   vertices {
#     x: 673
#     y: 575
#   }
# }
# , description: "SE"
# bounding_poly {
#   vertices {
#     x: 678
#     y: 551
#   }
#   vertices {
#     x: 705
#     y: 551
#   }
#   vertices {
#     x: 705
#     y: 575
#   }
#   vertices {
#     x: 678
#     y: 575
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 708
#     y: 551
#   }
#   vertices {
#     x: 714
#     y: 551
#   }
#   vertices {
#     x: 714
#     y: 575
#   }
#   vertices {
#     x: 708
#     y: 575
#   }
# }
# , description: ";"
# bounding_poly {
#   vertices {
#     x: 718
#     y: 551
#   }
#   vertices {
#     x: 724
#     y: 551
#   }
#   vertices {
#     x: 724
#     y: 575
#   }
#   vertices {
#     x: 718
#     y: 575
#   }
# }
# , description: "Tao"
# bounding_poly {
#   vertices {
#     x: 738
#     y: 551
#   }
#   vertices {
#     x: 769
#     y: 551
#   }
#   vertices {
#     x: 769
#     y: 575
#   }
#   vertices {
#     x: 738
#     y: 575
#   }
# }
# , description: "Cui"
# bounding_poly {
#   vertices {
#     x: 398
#     y: 579
#   }
#   vertices {
#     x: 438
#     y: 579
#   }
#   vertices {
#     x: 438
#     y: 602
#   }
#   vertices {
#     x: 398
#     y: 602
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 437
#     y: 579
#   }
#   vertices {
#     x: 443
#     y: 579
#   }
#   vertices {
#     x: 443
#     y: 602
#   }
#   vertices {
#     x: 437
#     y: 602
#   }
# }
# , description: "Upplands"
# bounding_poly {
#   vertices {
#     x: 451
#     y: 579
#   }
#   vertices {
#     x: 546
#     y: 579
#   }
#   vertices {
#     x: 546
#     y: 602
#   }
#   vertices {
#     x: 451
#     y: 602
#   }
# }
# , description: "V\303\244sby"
# bounding_poly {
#   vertices {
#     x: 558
#     y: 579
#   }
#   vertices {
#     x: 614
#     y: 579
#   }
#   vertices {
#     x: 614
#     y: 602
#   }
#   vertices {
#     x: 558
#     y: 602
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 627
#     y: 579
#   }
#   vertices {
#     x: 633
#     y: 579
#   }
#   vertices {
#     x: 633
#     y: 602
#   }
#   vertices {
#     x: 627
#     y: 602
#   }
# }
# , description: "SE"
# bounding_poly {
#   vertices {
#     x: 634
#     y: 579
#   }
#   vertices {
#     x: 660
#     y: 579
#   }
#   vertices {
#     x: 660
#     y: 602
#   }
#   vertices {
#     x: 634
#     y: 602
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 663
#     y: 579
#   }
#   vertices {
#     x: 669
#     y: 579
#   }
#   vertices {
#     x: 669
#     y: 602
#   }
#   vertices {
#     x: 663
#     y: 602
#   }
# }
# , description: ";"
# bounding_poly {
#   vertices {
#     x: 670
#     y: 579
#   }
#   vertices {
#     x: 676
#     y: 579
#   }
#   vertices {
#     x: 676
#     y: 602
#   }
#   vertices {
#     x: 670
#     y: 602
#   }
# }
# , description: "Mats"
# bounding_poly {
#   vertices {
#     x: 681
#     y: 579
#   }
#   vertices {
#     x: 740
#     y: 579
#   }
#   vertices {
#     x: 740
#     y: 602
#   }
#   vertices {
#     x: 681
#     y: 602
#   }
# }
# , description: "Folke"
# bounding_poly {
#   vertices {
#     x: 749
#     y: 579
#   }
#   vertices {
#     x: 805
#     y: 579
#   }
#   vertices {
#     x: 805
#     y: 602
#   }
#   vertices {
#     x: 749
#     y: 602
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 809
#     y: 579
#   }
#   vertices {
#     x: 815
#     y: 579
#   }
#   vertices {
#     x: 815
#     y: 602
#   }
#   vertices {
#     x: 809
#     y: 602
#   }
# }
# , description: "V\303\244llingby"
# bounding_poly {
#   vertices {
#     x: 403
#     y: 606
#   }
#   vertices {
#     x: 494
#     y: 606
#   }
#   vertices {
#     x: 494
#     y: 630
#   }
#   vertices {
#     x: 403
#     y: 630
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 506
#     y: 606
#   }
#   vertices {
#     x: 512
#     y: 606
#   }
#   vertices {
#     x: 512
#     y: 630
#   }
#   vertices {
#     x: 506
#     y: 630
#   }
# }
# , description: "SE"
# bounding_poly {
#   vertices {
#     x: 513
#     y: 606
#   }
#   vertices {
#     x: 540
#     y: 606
#   }
#   vertices {
#     x: 540
#     y: 630
#   }
#   vertices {
#     x: 513
#     y: 630
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 543
#     y: 606
#   }
#   vertices {
#     x: 549
#     y: 606
#   }
#   vertices {
#     x: 549
#     y: 630
#   }
#   vertices {
#     x: 543
#     y: 630
#   }
# }
# , description: ";"
# bounding_poly {
#   vertices {
#     x: 551
#     y: 606
#   }
#   vertices {
#     x: 557
#     y: 606
#   }
#   vertices {
#     x: 557
#     y: 630
#   }
#   vertices {
#     x: 551
#     y: 630
#   }
# }
# , description: "Gunnar"
# bounding_poly {
#   vertices {
#     x: 565
#     y: 606
#   }
#   vertices {
#     x: 649
#     y: 606
#   }
#   vertices {
#     x: 649
#     y: 630
#   }
#   vertices {
#     x: 565
#     y: 630
#   }
# }
# , description: "Mildh"
# bounding_poly {
#   vertices {
#     x: 655
#     y: 606
#   }
#   vertices {
#     x: 719
#     y: 606
#   }
#   vertices {
#     x: 719
#     y: 630
#   }
#   vertices {
#     x: 655
#     y: 630
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 723
#     y: 606
#   }
#   vertices {
#     x: 729
#     y: 606
#   }
#   vertices {
#     x: 729
#     y: 630
#   }
#   vertices {
#     x: 723
#     y: 630
#   }
# }
# , description: "Sollentuna"
# bounding_poly {
#   vertices {
#     x: 398
#     y: 634
#   }
#   vertices {
#     x: 503
#     y: 634
#   }
#   vertices {
#     x: 503
#     y: 658
#   }
#   vertices {
#     x: 398
#     y: 658
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 517
#     y: 634
#   }
#   vertices {
#     x: 523
#     y: 634
#   }
#   vertices {
#     x: 523
#     y: 658
#   }
#   vertices {
#     x: 517
#     y: 658
#   }
# }
# , description: "SE"
# bounding_poly {
#   vertices {
#     x: 522
#     y: 634
#   }
#   vertices {
#     x: 549
#     y: 634
#   }
#   vertices {
#     x: 549
#     y: 658
#   }
#   vertices {
#     x: 522
#     y: 658
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 552
#     y: 634
#   }
#   vertices {
#     x: 558
#     y: 634
#   }
#   vertices {
#     x: 558
#     y: 658
#   }
#   vertices {
#     x: 552
#     y: 658
#   }
# }
# , description: ";"
# bounding_poly {
#   vertices {
#     x: 560
#     y: 634
#   }
#   vertices {
#     x: 566
#     y: 634
#   }
#   vertices {
#     x: 566
#     y: 658
#   }
#   vertices {
#     x: 560
#     y: 658
#   }
# }
# , description: "Elena"
# bounding_poly {
#   vertices {
#     x: 578
#     y: 634
#   }
#   vertices {
#     x: 633
#     y: 634
#   }
#   vertices {
#     x: 633
#     y: 658
#   }
#   vertices {
#     x: 578
#     y: 658
#   }
# }
# , description: "Myhre"
# bounding_poly {
#   vertices {
#     x: 642
#     y: 634
#   }
#   vertices {
#     x: 715
#     y: 634
#   }
#   vertices {
#     x: 715
#     y: 658
#   }
#   vertices {
#     x: 642
#     y: 658
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 717
#     y: 634
#   }
#   vertices {
#     x: 723
#     y: 634
#   }
#   vertices {
#     x: 723
#     y: 658
#   }
#   vertices {
#     x: 717
#     y: 658
#   }
# }
# , description: "J\303\244rf\303\244lla"
# bounding_poly {
#   vertices {
#     x: 733
#     y: 634
#   }
#   vertices {
#     x: 801
#     y: 634
#   }
#   vertices {
#     x: 801
#     y: 658
#   }
#   vertices {
#     x: 733
#     y: 658
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 400
#     y: 662
#   }
#   vertices {
#     x: 406
#     y: 662
#   }
#   vertices {
#     x: 406
#     y: 686
#   }
#   vertices {
#     x: 400
#     y: 686
#   }
# }
# , description: "SE"
# bounding_poly {
#   vertices {
#     x: 407
#     y: 662
#   }
#   vertices {
#     x: 434
#     y: 662
#   }
#   vertices {
#     x: 434
#     y: 686
#   }
#   vertices {
#     x: 407
#     y: 686
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 437
#     y: 662
#   }
#   vertices {
#     x: 443
#     y: 662
#   }
#   vertices {
#     x: 443
#     y: 686
#   }
#   vertices {
#     x: 437
#     y: 686
#   }
# }
# , description: ";"
# bounding_poly {
#   vertices {
#     x: 445
#     y: 662
#   }
#   vertices {
#     x: 451
#     y: 662
#   }
#   vertices {
#     x: 451
#     y: 686
#   }
#   vertices {
#     x: 445
#     y: 686
#   }
# }
# , description: "Mikael"
# bounding_poly {
#   vertices {
#     x: 457
#     y: 662
#   }
#   vertices {
#     x: 533
#     y: 662
#   }
#   vertices {
#     x: 533
#     y: 686
#   }
#   vertices {
#     x: 457
#     y: 686
#   }
# }
# , description: "Wittberg"
# bounding_poly {
#   vertices {
#     x: 543
#     y: 662
#   }
#   vertices {
#     x: 638
#     y: 662
#   }
#   vertices {
#     x: 638
#     y: 686
#   }
#   vertices {
#     x: 543
#     y: 686
#   }
# }
# , description: ","
# bounding_poly {
#   vertices {
#     x: 640
#     y: 662
#   }
#   vertices {
#     x: 646
#     y: 662
#   }
#   vertices {
#     x: 646
#     y: 686
#   }
#   vertices {
#     x: 640
#     y: 686
#   }
# }
# , description: "Uppsala"
# bounding_poly {
#   vertices {
#     x: 655
#     y: 662
#   }
#   vertices {
#     x: 734
#     y: 662
#   }
#   vertices {
#     x: 734
#     y: 686
#   }
#   vertices {
#     x: 655
#     y: 686
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 745
#     y: 662
#   }
#   vertices {
#     x: 751
#     y: 662
#   }
#   vertices {
#     x: 751
#     y: 686
#   }
#   vertices {
#     x: 745
#     y: 686
#   }
# }
# , description: "SE"
# bounding_poly {
#   vertices {
#     x: 752
#     y: 662
#   }
#   vertices {
#     x: 779
#     y: 662
#   }
#   vertices {
#     x: 779
#     y: 686
#   }
#   vertices {
#     x: 752
#     y: 686
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 782
#     y: 662
#   }
#   vertices {
#     x: 788
#     y: 662
#   }
#   vertices {
#     x: 788
#     y: 686
#   }
#   vertices {
#     x: 782
#     y: 686
#   }
# }
# , description: "2009"
# bounding_poly {
#   vertices {
#     x: 877
#     y: 618
#   }
#   vertices {
#     x: 920
#     y: 618
#   }
#   vertices {
#     x: 920
#     y: 638
#   }
#   vertices {
#     x: 877
#     y: 638
#   }
# }
# , description: "/"
# bounding_poly {
#   vertices {
#     x: 921
#     y: 618
#   }
#   vertices {
#     x: 926
#     y: 618
#   }
#   vertices {
#     x: 926
#     y: 638
#   }
#   vertices {
#     x: 921
#     y: 638
#   }
# }
# , description: "0186624"
# bounding_poly {
#   vertices {
#     x: 928
#     y: 618
#   }
#   vertices {
#     x: 1000
#     y: 618
#   }
#   vertices {
#     x: 1000
#     y: 638
#   }
#   vertices {
#     x: 928
#     y: 638
#   }
# }
# , description: "Al"
# bounding_poly {
#   vertices {
#     x: 1016
#     y: 618
#   }
#   vertices {
#     x: 1046
#     y: 618
#   }
#   vertices {
#     x: 1046
#     y: 638
#   }
#   vertices {
#     x: 1016
#     y: 638
#   }
# }
# , description: "*"
# bounding_poly {
#   vertices {
#     x: 1049
#     y: 618
#   }
#   vertices {
#     x: 1054
#     y: 618
#   }
#   vertices {
#     x: 1054
#     y: 638
#   }
#   vertices {
#     x: 1049
#     y: 638
#   }
# }
# , description: "7"
# bounding_poly {
#   vertices {
#     x: 1089
#     y: 618
#   }
#   vertices {
#     x: 1094
#     y: 618
#   }
#   vertices {
#     x: 1094
#     y: 638
#   }
#   vertices {
#     x: 1089
#     y: 638
#   }
# }
# , description: "/"
# bounding_poly {
#   vertices {
#     x: 1098
#     y: 618
#   }
#   vertices {
#     x: 1103
#     y: 618
#   }
#   vertices {
#     x: 1103
#     y: 638
#   }
#   vertices {
#     x: 1098
#     y: 638
#   }
# }
# , description: "2009"
# bounding_poly {
#   vertices {
#     x: 1102
#     y: 618
#   }
#   vertices {
#     x: 1144
#     y: 618
#   }
#   vertices {
#     x: 1144
#     y: 638
#   }
#   vertices {
#     x: 1102
#     y: 638
#   }
# }
# , description: "Cave"
# bounding_poly {
#   vertices {
#     x: 1164
#     y: 618
#   }
#   vertices {
#     x: 1210
#     y: 618
#   }
#   vertices {
#     x: 1210
#     y: 638
#   }
#   vertices {
#     x: 1164
#     y: 638
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1220
#     y: 618
#   }
#   vertices {
#     x: 1225
#     y: 618
#   }
#   vertices {
#     x: 1225
#     y: 638
#   }
#   vertices {
#     x: 1220
#     y: 638
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1226
#     y: 618
#   }
#   vertices {
#     x: 1231
#     y: 618
#   }
#   vertices {
#     x: 1231
#     y: 638
#   }
#   vertices {
#     x: 1226
#     y: 638
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1232
#     y: 618
#   }
#   vertices {
#     x: 1237
#     y: 618
#   }
#   vertices {
#     x: 1237
#     y: 638
#   }
#   vertices {
#     x: 1232
#     y: 638
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1236
#     y: 618
#   }
#   vertices {
#     x: 1241
#     y: 618
#   }
#   vertices {
#     x: 1241
#     y: 638
#   }
#   vertices {
#     x: 1236
#     y: 638
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1242
#     y: 618
#   }
#   vertices {
#     x: 1247
#     y: 618
#   }
#   vertices {
#     x: 1247
#     y: 638
#   }
#   vertices {
#     x: 1242
#     y: 638
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1248
#     y: 618
#   }
#   vertices {
#     x: 1253
#     y: 618
#   }
#   vertices {
#     x: 1253
#     y: 638
#   }
#   vertices {
#     x: 1248
#     y: 638
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1253
#     y: 618
#   }
#   vertices {
#     x: 1258
#     y: 618
#   }
#   vertices {
#     x: 1258
#     y: 638
#   }
#   vertices {
#     x: 1253
#     y: 638
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1258
#     y: 618
#   }
#   vertices {
#     x: 1263
#     y: 618
#   }
#   vertices {
#     x: 1263
#     y: 638
#   }
#   vertices {
#     x: 1258
#     y: 638
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1266
#     y: 618
#   }
#   vertices {
#     x: 1271
#     y: 618
#   }
#   vertices {
#     x: 1271
#     y: 638
#   }
#   vertices {
#     x: 1266
#     y: 638
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 1270
#     y: 618
# ...
#   vertices {
#     x: 888
#     y: 1440
#   }
#   vertices {
#     x: 988
#     y: 1440
#   }
#   vertices {
#     x: 988
#     y: 1464
#   }
#   vertices {
#     x: 888
#     y: 1464
#   }
# }
# , description: "that"
# bounding_poly {
#   vertices {
#     x: 998
#     y: 1440
#   }
#   vertices {
#     x: 1035
#     y: 1440
#   }
#   vertices {
#     x: 1035
#     y: 1464
#   }
#   vertices {
#     x: 998
#     y: 1464
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 1045
#     y: 1440
#   }
#   vertices {
#     x: 1051
#     y: 1440
#   }
#   vertices {
#     x: 1051
#     y: 1464
#   }
#   vertices {
#     x: 1045
#     y: 1464
#   }
# }
# , description: "problem"
# bounding_poly {
#   vertices {
#     x: 1061
#     y: 1440
#   }
#   vertices {
#     x: 1135
#     y: 1440
#   }
#   vertices {
#     x: 1135
#     y: 1464
#   }
#   vertices {
#     x: 1061
#     y: 1464
#   }
# }
# , description: "with"
# bounding_poly {
#   vertices {
#     x: 1152
#     y: 1440
#   }
#   vertices {
#     x: 1191
#     y: 1440
#   }
#   vertices {
#     x: 1191
#     y: 1464
#   }
#   vertices {
#     x: 1152
#     y: 1464
#   }
# }
# , description: "the"
# bounding_poly {
#   vertices {
#     x: 1206
#     y: 1440
#   }
#   vertices {
#     x: 1237
#     y: 1440
#   }
#   vertices {
#     x: 1237
#     y: 1464
#   }
#   vertices {
#     x: 1206
#     y: 1464
#   }
# }
# , description: "random"
# bounding_poly {
#   vertices {
#     x: 1246
#     y: 1440
#   }
#   vertices {
#     x: 1311
#     y: 1440
#   }
#   vertices {
#     x: 1311
#     y: 1464
#   }
#   vertices {
#     x: 1246
#     y: 1464
#   }
# }
# , description: "access"
# bounding_poly {
#   vertices {
#     x: 1330
#     y: 1440
#   }
#   vertices {
#     x: 1390
#     y: 1440
#   }
#   vertices {
#     x: 1390
#     y: 1464
#   }
#   vertices {
#     x: 1330
#     y: 1464
#   }
# }
# , description: "proce"
# bounding_poly {
#   vertices {
#     x: 1402
#     y: 1440
#   }
#   vertices {
#     x: 1462
#     y: 1440
#   }
#   vertices {
#     x: 1462
#     y: 1464
#   }
#   vertices {
#     x: 1402
#     y: 1464
#   }
# }
# , description: "dure"
# bounding_poly {
#   vertices {
#     x: 915
#     y: 1468
#   }
#   vertices {
#     x: 956
#     y: 1468
#   }
#   vertices {
#     x: 956
#     y: 1492
#   }
#   vertices {
#     x: 915
#     y: 1492
#   }
# }
# , description: "has"
# bounding_poly {
#   vertices {
#     x: 965
#     y: 1468
#   }
#   vertices {
#     x: 1000
#     y: 1468
#   }
#   vertices {
#     x: 1000
#     y: 1492
#   }
#   vertices {
#     x: 965
#     y: 1492
#   }
# }
# , description: "occurred"
# bounding_poly {
#   vertices {
#     x: 1009
#     y: 1468
#   }
#   vertices {
#     x: 1089
#     y: 1468
#   }
#   vertices {
#     x: 1089
#     y: 1492
#   }
#   vertices {
#     x: 1009
#     y: 1492
#   }
# }
# , description: "when"
# bounding_poly {
#   vertices {
#     x: 1098
#     y: 1468
#   }
#   vertices {
#     x: 1149
#     y: 1468
#   }
#   vertices {
#     x: 1149
#     y: 1492
#   }
#   vertices {
#     x: 1098
#     y: 1492
#   }
# }
# , description: "a"
# bounding_poly {
#   vertices {
#     x: 1162
#     y: 1468
#   }
#   vertices {
#     x: 1168
#     y: 1468
#   }
#   vertices {
#     x: 1168
#     y: 1492
#   }
#   vertices {
#     x: 1162
#     y: 1492
#   }
# }
# , description: "certain"
# bounding_poly {
#   vertices {
#     x: 1181
#     y: 1468
#   }
#   vertices {
#     x: 1243
#     y: 1468
#   }
#   vertices {
#     x: 1243
#     y: 1492
#   }
#   vertices {
#     x: 1181
#     y: 1492
#   }
# }
# , description: "condition"
# bounding_poly {
#   vertices {
#     x: 1256
#     y: 1468
#   }
#   vertices {
#     x: 1345
#     y: 1468
#   }
#   vertices {
#     x: 1345
#     y: 1492
#   }
#   vertices {
#     x: 1256
#     y: 1492
#   }
# }
# , description: "is"
# bounding_poly {
#   vertices {
#     x: 1357
#     y: 1468
#   }
#   vertices {
#     x: 1370
#     y: 1468
#   }
#   vertices {
#     x: 1370
#     y: 1492
#   }
#   vertices {
#     x: 1357
#     y: 1492
#   }
# }
# , description: "fulfilled"
# bounding_poly {
#   vertices {
#     x: 1379
#     y: 1468
#   }
#   vertices {
#     x: 1454
#     y: 1468
#   }
#   vertices {
#     x: 1454
#     y: 1492
#   }
#   vertices {
#     x: 1379
#     y: 1492
#   }
# }
# , description: ";"
# bounding_poly {
#   vertices {
#     x: 1459
#     y: 1468
#   }
#   vertices {
#     x: 1465
#     y: 1468
#   }
#   vertices {
#     x: 1465
#     y: 1492
#   }
#   vertices {
#     x: 1459
#     y: 1492
#   }
# }
# , description: "and"
# bounding_poly {
#   vertices {
#     x: 914
#     y: 1497
#   }
#   vertices {
#     x: 947
#     y: 1497
#   }
#   vertices {
#     x: 947
#     y: 1518
#   }
#   vertices {
#     x: 914
#     y: 1518
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 1132
#     y: 1528
#   }
#   vertices {
#     x: 1138
#     y: 1528
#   }
#   vertices {
#     x: 1138
#     y: 1553
#   }
#   vertices {
#     x: 1132
#     y: 1553
#   }
# }
# , description: "Continued"
# bounding_poly {
#   vertices {
#     x: 1137
#     y: 1528
#   }
#   vertices {
#     x: 1238
#     y: 1528
#   }
#   vertices {
#     x: 1238
#     y: 1553
#   }
#   vertices {
#     x: 1137
#     y: 1553
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 1241
#     y: 1528
#   }
#   vertices {
#     x: 1247
#     y: 1528
#   }
#   vertices {
#     x: 1247
#     y: 1553
#   }
#   vertices {
#     x: 1241
#     y: 1553
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 218
#     y: 1472
#   }
#   vertices {
#     x: 224
#     y: 1472
#   }
#   vertices {
#     x: 224
#     y: 1496
#   }
#   vertices {
#     x: 218
#     y: 1496
#   }
# }
# , description: "51"
# bounding_poly {
#   vertices {
#     x: 223
#     y: 1472
#   }
#   vertices {
#     x: 249
#     y: 1472
#   }
#   vertices {
#     x: 249
#     y: 1496
#   }
#   vertices {
#     x: 223
#     y: 1496
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 249
#     y: 1472
#   }
#   vertices {
#     x: 255
#     y: 1472
#   }
#   vertices {
#     x: 255
#     y: 1496
#   }
#   vertices {
#     x: 249
#     y: 1496
#   }
# }
# , description: "Int"
# bounding_poly {
#   vertices {
#     x: 286
#     y: 1472
#   }
#   vertices {
#     x: 313
#     y: 1472
#   }
#   vertices {
#     x: 313
#     y: 1496
#   }
#   vertices {
#     x: 286
#     y: 1496
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 315
#     y: 1472
#   }
#   vertices {
#     x: 321
#     y: 1472
#   }
#   vertices {
#     x: 321
#     y: 1496
#   }
#   vertices {
#     x: 315
#     y: 1496
#   }
# }
# , description: "Cl"
# bounding_poly {
#   vertices {
#     x: 330
#     y: 1472
#   }
#   vertices {
#     x: 357
#     y: 1472
#   }
#   vertices {
#     x: 357
#     y: 1496
#   }
#   vertices {
#     x: 330
#     y: 1496
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 355
#     y: 1472
#   }
#   vertices {
#     x: 361
#     y: 1472
#   }
#   vertices {
#     x: 361
#     y: 1496
#   }
#   vertices {
#     x: 355
#     y: 1496
#   }
# }
# , description: "H04W"
# bounding_poly {
#   vertices {
#     x: 283
#     y: 1499
#   }
#   vertices {
#     x: 339
#     y: 1499
#   }
#   vertices {
#     x: 339
#     y: 1524
#   }
#   vertices {
#     x: 283
#     y: 1524
#   }
# }
# , description: "74"
# bounding_poly {
#   vertices {
#     x: 357
#     y: 1499
#   }
#   vertices {
#     x: 380
#     y: 1499
#   }
#   vertices {
#     x: 380
#     y: 1524
#   }
#   vertices {
#     x: 357
#     y: 1524
#   }
# }
# , description: "/"
# bounding_poly {
#   vertices {
#     x: 383
#     y: 1499
#   }
#   vertices {
#     x: 389
#     y: 1499
#   }
#   vertices {
#     x: 389
#     y: 1524
#   }
#   vertices {
#     x: 383
#     y: 1524
#   }
# }
# , description: "08"
# bounding_poly {
#   vertices {
#     x: 389
#     y: 1499
#   }
#   vertices {
#     x: 412
#     y: 1499
#   }
#   vertices {
#     x: 412
#     y: 1524
#   }
#   vertices {
#     x: 389
#     y: 1524
#   }
# }
# , description: "H04L"
# bounding_poly {
#   vertices {
#     x: 281
#     y: 1530
#   }
#   vertices {
#     x: 337
#     y: 1530
#   }
#   vertices {
#     x: 337
#     y: 1551
#   }
#   vertices {
#     x: 281
#     y: 1551
#   }
# }
# , description: "12"
# bounding_poly {
#   vertices {
#     x: 352
#     y: 1530
#   }
#   vertices {
#     x: 371
#     y: 1530
#   }
#   vertices {
#     x: 371
#     y: 1551
#   }
#   vertices {
#     x: 352
#     y: 1551
#   }
# }
# , description: "/"
# bounding_poly {
#   vertices {
#     x: 375
#     y: 1530
#   }
#   vertices {
#     x: 380
#     y: 1530
#   }
#   vertices {
#     x: 380
#     y: 1551
#   }
#   vertices {
#     x: 375
#     y: 1551
#   }
# }
# , description: "24"
# bounding_poly {
#   vertices {
#     x: 380
#     y: 1530
#   }
#   vertices {
#     x: 403
#     y: 1530
#   }
#   vertices {
#     x: 403
#     y: 1551
#   }
#   vertices {
#     x: 380
#     y: 1551
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 518
#     y: 1502
#   }
#   vertices {
#     x: 523
#     y: 1502
#   }
#   vertices {
#     x: 523
#     y: 1523
#   }
#   vertices {
#     x: 518
#     y: 1523
#   }
# }
# , description: "2009"
# bounding_poly {
#   vertices {
#     x: 525
#     y: 1502
#   }
#   vertices {
#     x: 571
#     y: 1502
#   }
#   vertices {
#     x: 571
#     y: 1523
#   }
#   vertices {
#     x: 525
#     y: 1523
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 573
#     y: 1502
#   }
#   vertices {
#     x: 578
#     y: 1502
#   }
#   vertices {
#     x: 578
#     y: 1523
#   }
#   vertices {
#     x: 573
#     y: 1523
#   }
# }
# , description: "01"
# bounding_poly {
#   vertices {
#     x: 579
#     y: 1502
#   }
#   vertices {
#     x: 602
#     y: 1502
#   }
#   vertices {
#     x: 602
#     y: 1523
#   }
#   vertices {
#     x: 579
#     y: 1523
#   }
# }
# , description: "("
# bounding_poly {
#   vertices {
#     x: 518
#     y: 1530
#   }
#   vertices {
#     x: 523
#     y: 1530
#   }
#   vertices {
#     x: 523
#     y: 1552
#   }
#   vertices {
#     x: 518
#     y: 1552
#   }
# }
# , description: "2006"
# bounding_poly {
#   vertices {
#     x: 526
#     y: 1530
#   }
#   vertices {
#     x: 568
#     y: 1530
#   }
#   vertices {
#     x: 568
#     y: 1552
#   }
#   vertices {
#     x: 526
#     y: 1552
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 573
#     y: 1530
#   }
#   vertices {
#     x: 578
#     y: 1530
#   }
#   vertices {
#     x: 578
#     y: 1552
#   }
#   vertices {
#     x: 573
#     y: 1552
#   }
# }
# , description: "01"
# bounding_poly {
#   vertices {
#     x: 580
#     y: 1530
#   }
#   vertices {
#     x: 604
#     y: 1530
#   }
#   vertices {
#     x: 604
#     y: 1552
#   }
#   vertices {
#     x: 580
#     y: 1552
#   }
# }
# , description: ")"
# bounding_poly {
#   vertices {
#     x: 606
#     y: 1530
#   }
#   vertices {
#     x: 611
#     y: 1530
#   }
#   vertices {
#     x: 611
#     y: 1552
#   }
#   vertices {
#     x: 606
#     y: 1552
#   }
# }
# , description: "Dr10"
# bounding_poly {
#   vertices {
#     x: 652
#     y: 1660
#   }
#   vertices {
#     x: 725
#     y: 1621
#   }
#   vertices {
#     x: 741
#     y: 1651
#   }
#   vertices {
#     x: 667
#     y: 1689
#   }
# }
# , description: "301"
# bounding_poly {
#   vertices {
#     x: 759
#     y: 1739
#   }
#   vertices {
#     x: 786
#     y: 1739
#   }
#   vertices {
#     x: 786
#     y: 1757
#   }
#   vertices {
#     x: 759
#     y: 1757
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 783
#     y: 1739
#   }
#   vertices {
#     x: 787
#     y: 1739
#   }
#   vertices {
#     x: 787
#     y: 1757
#   }
#   vertices {
#     x: 783
#     y: 1757
#   }
# }
# , description: "Initiate"
# bounding_poly {
#   vertices {
#     x: 793
#     y: 1739
#   }
#   vertices {
#     x: 835
#     y: 1739
#   }
#   vertices {
#     x: 835
#     y: 1757
#   }
#   vertices {
#     x: 793
#     y: 1757
#   }
# }
# , description: "RA"
# bounding_poly {
#   vertices {
#     x: 843
#     y: 1739
#   }
#   vertices {
#     x: 859
#     y: 1739
#   }
#   vertices {
#     x: 859
#     y: 1757
#   }
#   vertices {
#     x: 843
#     y: 1757
#   }
# }
# , description: "procedure"
# bounding_poly {
#   vertices {
#     x: 869
#     y: 1739
#   }
#   vertices {
#     x: 934
#     y: 1739
#   }
#   vertices {
#     x: 934
#     y: 1757
#   }
#   vertices {
#     x: 869
#     y: 1757
#   }
# }
# , description: "302"
# bounding_poly {
#   vertices {
#     x: 631
#     y: 1786
#   }
#   vertices {
#     x: 653
#     y: 1786
#   }
#   vertices {
#     x: 653
#     y: 1803
#   }
#   vertices {
#     x: 631
#     y: 1803
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 652
#     y: 1786
#   }
#   vertices {
#     x: 656
#     y: 1786
#   }
#   vertices {
#     x: 656
#     y: 1803
#   }
#   vertices {
#     x: 652
#     y: 1803
#   }
# }
# , description: "Select"
# bounding_poly {
#   vertices {
#     x: 664
#     y: 1786
#   }
#   vertices {
#     x: 703
#     y: 1786
#   }
#   vertices {
#     x: 703
#     y: 1803
#   }
#   vertices {
#     x: 664
#     y: 1803
#   }
# }
# , description: "RA"
# bounding_poly {
#   vertices {
#     x: 710
#     y: 1786
#   }
#   vertices {
#     x: 728
#     y: 1786
#   }
#   vertices {
#     x: 728
#     y: 1803
#   }
#   vertices {
#     x: 710
#     y: 1803
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 732
#     y: 1786
#   }
#   vertices {
#     x: 736
#     y: 1786
#   }
#   vertices {
#     x: 736
#     y: 1803
#   }
#   vertices {
#     x: 732
#     y: 1803
#   }
# }
# , description: "preamble"
# bounding_poly {
#   vertices {
#     x: 647
#     y: 1806
#   }
#   vertices {
#     x: 707
#     y: 1806
#   }
#   vertices {
#     x: 707
#     y: 1823
#   }
#   vertices {
#     x: 647
#     y: 1823
#   }
# }
# , description: "303"
# bounding_poly {
#   vertices {
#     x: 605
#     y: 1849
#   }
#   vertices {
#     x: 627
#     y: 1849
#   }
#   vertices {
#     x: 627
#     y: 1866
#   }
#   vertices {
#     x: 605
#     y: 1866
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 629
#     y: 1849
#   }
#   vertices {
#     x: 633
#     y: 1849
#   }
#   vertices {
#     x: 633
#     y: 1866
#   }
#   vertices {
#     x: 629
#     y: 1866
#   }
# }
# , description: "Determine"
# bounding_poly {
#   vertices {
#     x: 638
#     y: 1849
#   }
#   vertices {
#     x: 706
#     y: 1850
#   }
#   vertices {
#     x: 706
#     y: 1868
#   }
#   vertices {
#     x: 638
#     y: 1867
#   }
# }
# , description: "problem"
# bounding_poly {
#   vertices {
#     x: 713
#     y: 1850
#   }
#   vertices {
#     x: 759
#     y: 1851
#   }
#   vertices {
#     x: 759
#     y: 1869
#   }
#   vertices {
#     x: 713
#     y: 1868
#   }
# }
# , description: "with"
# bounding_poly {
#   vertices {
#     x: 621
#     y: 1870
#   }
#   vertices {
#     x: 645
#     y: 1870
#   }
#   vertices {
#     x: 645
#     y: 1886
#   }
#   vertices {
#     x: 621
#     y: 1886
#   }
# }
# , description: "RA"
# bounding_poly {
#   vertices {
#     x: 654
#     y: 1870
#   }
#   vertices {
#     x: 671
#     y: 1870
#   }
#   vertices {
#     x: 671
#     y: 1886
#   }
#   vertices {
#     x: 654
#     y: 1886
#   }
# }
# , description: "procedure"
# bounding_poly {
#   vertices {
#     x: 678
#     y: 1870
#   }
#   vertices {
#     x: 745
#     y: 1870
#   }
#   vertices {
#     x: 745
#     y: 1886
#   }
#   vertices {
#     x: 678
#     y: 1886
#   }
# }
# , description: "304"
# bounding_poly {
#   vertices {
#     x: 610
#     y: 1908
#   }
#   vertices {
#     x: 631
#     y: 1908
#   }
#   vertices {
#     x: 631
#     y: 1926
#   }
#   vertices {
#     x: 610
#     y: 1926
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 633
#     y: 1908
#   }
#   vertices {
#     x: 637
#     y: 1908
#   }
#   vertices {
#     x: 637
#     y: 1926
#   }
#   vertices {
#     x: 633
#     y: 1926
#   }
# }
# , description: "Perform"
# bounding_poly {
#   vertices {
#     x: 643
#     y: 1908
#   }
#   vertices {
#     x: 689
#     y: 1909
#   }
#   vertices {
#     x: 689
#     y: 1928
#   }
#   vertices {
#     x: 643
#     y: 1927
#   }
# }
# , description: "an"
# bounding_poly {
#   vertices {
#     x: 701
#     y: 1909
#   }
#   vertices {
#     x: 713
#     y: 1909
#   }
#   vertices {
#     x: 713
#     y: 1927
#   }
#   vertices {
#     x: 701
#     y: 1927
#   }
# }
# , description: "action"
# bounding_poly {
#   vertices {
#     x: 724
#     y: 1910
#   }
#   vertices {
#     x: 760
#     y: 1910
#   }
#   vertices {
#     x: 760
#     y: 1928
#   }
#   vertices {
#     x: 724
#     y: 1928
#   }
# }
# , description: "3041"
# bounding_poly {
#   vertices {
#     x: 648
#     y: 1936
#   }
#   vertices {
#     x: 680
#     y: 1936
#   }
#   vertices {
#     x: 680
#     y: 1954
#   }
#   vertices {
#     x: 648
#     y: 1954
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 680
#     y: 1936
#   }
#   vertices {
#     x: 684
#     y: 1936
#   }
#   vertices {
#     x: 684
#     y: 1954
#   }
#   vertices {
#     x: 680
#     y: 1954
#   }
# }
# , description: "Delay"
# bounding_poly {
#   vertices {
#     x: 690
#     y: 1936
#   }
#   vertices {
#     x: 727
#     y: 1936
#   }
#   vertices {
#     x: 727
#     y: 1954
#   }
#   vertices {
#     x: 690
#     y: 1954
#   }
# }
# , description: "3042"
# bounding_poly {
#   vertices {
#     x: 651
#     y: 1973
#   }
#   vertices {
#     x: 682
#     y: 1973
#   }
#   vertices {
#     x: 682
#     y: 1989
#   }
#   vertices {
#     x: 651
#     y: 1989
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 683
#     y: 1973
#   }
#   vertices {
#     x: 687
#     y: 1973
#   }
#   vertices {
#     x: 687
#     y: 1989
#   }
#   vertices {
#     x: 683
#     y: 1989
#   }
# }
# , description: "Abort"
# bounding_poly {
#   vertices {
#     x: 690
#     y: 1973
#   }
#   vertices {
#     x: 728
#     y: 1973
#   }
#   vertices {
#     x: 728
#     y: 1989
#   }
#   vertices {
#     x: 690
#     y: 1989
#   }
# }
# , description: "3043"
# bounding_poly {
#   vertices {
#     x: 651
#     y: 2009
#   }
#   vertices {
#     x: 685
#     y: 2009
#   }
#   vertices {
#     x: 685
#     y: 2027
#   }
#   vertices {
#     x: 651
#     y: 2027
#   }
# }
# , description: "."
# bounding_poly {
#   vertices {
#     x: 685
#     y: 2009
#   }
#   vertices {
#     x: 689
#     y: 2009
#   }
#   vertices {
#     x: 689
#     y: 2027
#   }
#   vertices {
#     x: 685
#     y: 2027
#   }
# }
# , description: "Stop"
# bounding_poly {
#   vertices {
#     x: 695
#     y: 2009
#   }
#   vertices {
#     x: 722
#     y: 2009
#   }
#   vertices {
#     x: 722
#     y: 2027
#   }
#   vertices {
#     x: 695
#     y: 2027
#   }
# }
# ]
