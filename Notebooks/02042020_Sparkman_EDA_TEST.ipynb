# %%
from google.cloud import bigquery
import pandas

# %%
client = bigquery.Client(location="US")
print("Client creating using default project: {}".format(client.project))
# Out:
# Client creating using default project: ut-goog

# %% [markdown]
# # Looking at the first half of the columns from the dataset.

# %%
query = """
    SELECT 
        date_received, 
        product, subproduct, 
        issue, subissue, 
        consumer_complaint_narrative, 
        company_public_response, 
        company_name, 
        state 
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

complaints_df = query_job.to_dataframe()
complaints_df
# Out:
#         date_received                                            product  \
# 0          2017-03-26                                        Credit card
# 1          2020-04-17                        Credit card or prepaid card
# 2          2020-04-22  Money transfer, virtual currency, or money ser...
# 3          2020-04-03  Money transfer, virtual currency, or money ser...
# 4          2020-03-28  Money transfer, virtual currency, or money ser...
# ...               ...                                                ...
# 1579956    2019-02-22  Credit reporting, credit repair services, or o...
# 1579957    2019-02-22  Credit reporting, credit repair services, or o...
# 1579958    2019-02-26  Credit reporting, credit repair services, or o...
# 1579959    2019-02-26  Credit reporting, credit repair services, or o...
# 1579960    2018-12-22  Credit reporting, credit repair services, or o...
#
#                            subproduct  \
# 0                                None
# 1        General-purpose prepaid card
# 2               Check cashing service
# 3            Mobile or digital wallet
# 4        International money transfer
# ...                               ...
# 1579956              Credit reporting
# 1579957              Credit reporting
# 1579958              Credit reporting
# 1579959              Credit reporting
# 1579960              Credit reporting
#
#                                                      issue  \
# 0                                                 Late fee
# 1                                              Advertising
# 2                                            Fraud or scam
# 3                                            Fraud or scam
# 4                                            Fraud or scam
# ...                                                    ...
# 1579956  Problem with a credit reporting company's inve...
# 1579957  Problem with a credit reporting company's inve...
# 1579958  Problem with a credit reporting company's inve...
# 1579959  Problem with a credit reporting company's inve...
# 1579960  Problem with a credit reporting company's inve...
#
#                                                   subissue  \
# 0                                                     None
# 1        Confusing or misleading advertising about the ...
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 1579956  Their investigation did not fix an error on yo...
# 1579957  Difficulty submitting a dispute or getting inf...
# 1579958  Was not notified of investigation status or re...
# 1579959  Their investigation did not fix an error on yo...
# 1579960  Was not notified of investigation status or re...
#
#         consumer_complaint_narrative  \
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4                               None
# ...                              ...
# 1579956                         None
# 1579957                         None
# 1579958                         None
# 1579959                         None
# 1579960                         None
#
#                                    company_public_response  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 1579956                                               None
# 1579957  Company has responded to the consumer and the ...
# 1579958  Company has responded to the consumer and the ...
# 1579959  Company has responded to the consumer and the ...
# 1579960  Company has responded to the consumer and the ...
#
#                                     company_name state
# 0                    Alliance Data Card Services    IL
# 1                       AMERICAN EXPRESS COMPANY    NY
# 2                           JPMORGAN CHASE & CO.    CA
# 3                           JPMORGAN CHASE & CO.    TX
# 4                                  Remitly, Inc.    PA
# ...                                          ...   ...
# 1579956                            EQUIFAX, INC.    NY
# 1579957      Experian Information Solutions Inc.    NY
# 1579958      Experian Information Solutions Inc.    NY
# 1579959      Experian Information Solutions Inc.    NY
# 1579960  Receivables Performance Management, LLC    FL
#
# [1579961 rows x 9 columns]

# %% [markdown]
# # Looking at null values by column
# Percentage of missing values by columns

# %%
(complaints_df.isnull().sum()/len(complaints_df)*100).sort_values(ascending=False)
# Out:
# consumer_complaint_narrative    66.903170
# company_public_response         62.051848
# subissue                        35.865569
# subproduct                      14.884228
# state                            1.696941
# company_name                     0.000000
# issue                            0.000000
# product                          0.000000
# date_received                    0.000000
# dtype: float64

# %% [markdown]
# ### Can see that the narrative is the highest missing.

# %%
(len(complaints_df)-complaints_df.isnull().sum()).sort_values()
# Out:
# consumer_complaint_narrative     522917
# company_public_response          599566
# subissue                        1013299
# subproduct                      1344796
# state                           1553150
# date_received                   1579961
# product                         1579961
# issue                           1579961
# company_name                    1579961
# dtype: int64

# %% [markdown]
# ### We have half a million complaint narratives that we can use the NLP API on.

# %%
complaints_df.dtypes
# Out:
# date_received                   object
# product                         object
# subproduct                      object
# issue                           object
# subissue                        object
# consumer_complaint_narrative    object
# company_public_response         object
# company_name                    object
# state                           object
# dtype: object

# %% [markdown]
# ### Looking at Products and Subproducts

# %%
query = """
    SELECT 
        product, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        product
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

products_df = query_job.to_dataframe()
products_df
# Out:
#                                               product   total
# 0   Credit reporting, credit repair services, or o...  160495
# 1                                     Debt collection  112244
# 2                                            Mortgage   64071
# 3                         Credit card or prepaid card   35400
# 4                                    Credit reporting   31588
# 5                                        Student loan   25862
# 6                         Checking or savings account   20806
# 7                                         Credit card   18838
# 8                             Bank account or service   14885
# 9                                       Consumer Loan    9473
# 10                              Vehicle loan or lease    8843
# 11  Money transfer, virtual currency, or money ser...    8452
# 12          Payday loan, title loan, or personal loan    6959
# 13                                        Payday loan    1746
# 14                                    Money transfers    1497
# 15                                       Prepaid card    1450
# 16                            Other financial service     292
# 17                                   Virtual currency      16

# %%
products_df.plot(kind="bar",x='product')

# %%
products_df
# Out:
#                                               product   total
# 0   Credit reporting, credit repair services, or o...  160495
# 1                                     Debt collection  112244
# 2                                            Mortgage   64071
# 3                         Credit card or prepaid card   35400
# 4                                    Credit reporting   31588
# 5                                        Student loan   25862
# 6                         Checking or savings account   20806
# 7                                         Credit card   18838
# 8                             Bank account or service   14885
# 9                                       Consumer Loan    9473
# 10                              Vehicle loan or lease    8843
# 11  Money transfer, virtual currency, or money ser...    8452
# 12          Payday loan, title loan, or personal loan    6959
# 13                                        Payday loan    1746
# 14                                    Money transfers    1497
# 15                                       Prepaid card    1450
# 16                            Other financial service     292
# 17                                   Virtual currency      16

# %% [markdown]
# Most has to do with credit and debt. Also, notice that a lot of the labels are very similar (ie credit card, prepaid card, card card or prepaid card). Might have to find a way to wrap these up.

# %% [markdown]
# ### Look at and maybe combine some of the products?
# ### Could the different product labels be due to different companies? or maybe they changed over time with the form?

# %%
query = """
    SELECT 
        company_name, product, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        company_name, product
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

products2_df = query_job.to_dataframe()

# %%
products2_df[:10]
# Out:
#                              company_name  \
# 0                           EQUIFAX, INC.
# 1     Experian Information Solutions Inc.
# 2  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# 3                 Navient Solutions, LLC.
# 4                           EQUIFAX, INC.
# 5     Experian Information Solutions Inc.
# 6  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# 7                   WELLS FARGO & COMPANY
# 8                          CITIBANK, N.A.
# 9             Ocwen Financial Corporation
#
#                                              product  total
# 0  Credit reporting, credit repair services, or o...  44396
# 1  Credit reporting, credit repair services, or o...  40015
# 2  Credit reporting, credit repair services, or o...  38115
# 3                                       Student loan  12608
# 4                                   Credit reporting  11370
# 5                                   Credit reporting   9248
# 6                                   Credit reporting   9105
# 7                                           Mortgage   6422
# 8                        Credit card or prepaid card   5708
# 9                                           Mortgage   5136

# %%
products2_df[products2_df['company_name']=='EQUIFAX, INC.']
# Out:
#        company_name                                            product  total
# 0     EQUIFAX, INC.  Credit reporting, credit repair services, or o...  44396
# 4     EQUIFAX, INC.                                   Credit reporting  11370
# 88    EQUIFAX, INC.                                    Debt collection    817
# 550   EQUIFAX, INC.                        Credit card or prepaid card     91
# 1444  EQUIFAX, INC.                                           Mortgage     25
# 1534  EQUIFAX, INC.                                      Consumer Loan     23
# 1811  EQUIFAX, INC.                                       Student loan     18
# 1844  EQUIFAX, INC.                              Vehicle loan or lease     17
# 2319  EQUIFAX, INC.                                        Credit card     11
# 3282  EQUIFAX, INC.          Payday loan, title loan, or personal loan      6
# 3797  EQUIFAX, INC.  Money transfer, virtual currency, or money ser...      4
# 4321  EQUIFAX, INC.                        Checking or savings account      3
# 5840  EQUIFAX, INC.                            Bank account or service      2
# 9052  EQUIFAX, INC.                            Other financial service      1

# %%
products2_df[:10].plot(kind='bar',x='product')

# %% [markdown]
# Most complaints for the companies seem to be about credit cards or credit. Looks like the differing labels for the categories are not company related. This makes sense since the complaints go through the CFPB and thus are probably standardized. The differing labels may be due to the complaint form changing overtime.

# %% [markdown]
# ### Lets look at subproducts to see if there is a reason for the different product types

# %%
query = """
    SELECT 
        subproduct, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        subproduct
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

subproducts_df = query_job.to_dataframe()
subproducts_df
# Out:
#                                     subproduct   total
# 0                             Credit reporting  156987
# 1                                         None   52172
# 2                             Checking account   27395
# 3   General-purpose credit card or charge card   27015
# 4                                I do not know   22035
# ..                                         ...     ...
# 71                               Credit repair      39
# 72                 Traveler’s/Cashier’s checks      22
# 73                                Transit card      19
# 74                        Student prepaid card       4
# 75      Electronic Benefit Transfer / EBT card       3
#
# [76 rows x 2 columns]

# %%
query = """
    SELECT 
        product, subproduct, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        product, subproduct
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

products3_df = query_job.to_dataframe()
products3_df[:20]
# Out:
#                                               product  \
# 0   Credit reporting, credit repair services, or o...
# 1                                    Credit reporting
# 2                         Credit card or prepaid card
# 3                                     Debt collection
# 4                                     Debt collection
# 5                                            Mortgage
# 6                                         Credit card
# 7                         Checking or savings account
# 8                                     Debt collection
# 9                                        Student loan
# 10                                           Mortgage
# 11                                    Debt collection
# 12                                    Debt collection
# 13                                           Mortgage
# 14                            Bank account or service
# 15                                    Debt collection
# 16                              Vehicle loan or lease
# 17                                    Debt collection
# 18                        Credit card or prepaid card
# 19                                       Student loan
#
#                                     subproduct   total
# 0                             Credit reporting  156987
# 1                                         None   31588
# 2   General-purpose credit card or charge card   27015
# 3                                I do not know   22035
# 4                                   Other debt   20421
# 5                   Conventional home mortgage   18878
# 6                                         None   18838
# 7                             Checking account   17282
# 8                             Credit card debt   16030
# 9               Federal student loan servicing   14936
# 10                 Conventional fixed mortgage   14562
# 11       Other (i.e. phone, health club, etc.)   12389
# 12                                Medical debt   12313
# 13                                FHA mortgage   11934
# 14                            Checking account   10113
# 15                                 Credit card    7520
# 16                                        Loan    7231
# 17                                     Medical    6990
# 18                           Store credit card    6213
# 19                    Non-federal student loan    5753

# %% [markdown]
# Notice row 6, "I do not know". What does this mean? Looks like we can combine some subproducts, ie credit card debt and credit card or medical debt and medical

# %%
products3_df[products3_df['product'] == 'Credit card or prepaid card']
# Out:
#                         product                                  subproduct  \
# 2   Credit card or prepaid card  General-purpose credit card or charge card
# 18  Credit card or prepaid card                           Store credit card
# 44  Credit card or prepaid card                General-purpose prepaid card
# 61  Credit card or prepaid card                     Government benefit card
# 67  Credit card or prepaid card                                   Gift card
# 71  Credit card or prepaid card                                Payroll card
# 94  Credit card or prepaid card                        Student prepaid card
#
#     total
# 2   27015
# 18   6213
# 44   1456
# 61    409
# 67    160
# 71    143
# 94      4

# %% [markdown]
# The just credit card product has no subproduct but the one that combines credit card and prepaid card does. Do they mean different things?

# %% [markdown]
# # Looking at issues and subissues

# %%
query = """
    SELECT 
        issue, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        issue
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

issue_df = query_job.to_dataframe()
issue_df[:10]
# Out:
#                                                issue  total
# 0               Incorrect information on your report  89712
# 1  Problem with a credit reporting company's inve...  43422
# 2                  Attempts to collect debt not owed  31609
# 3                        Improper use of your report  21614
# 4             Incorrect information on credit report  21217
# 5              Cont'd attempts collect debt not owed  17434
# 6                     Trouble during payment process  14758
# 7           Loan servicing, payments, escrow account  14722
# 8                              Communication tactics  14366
# 9                    Written notification about debt  13531

# %% [markdown]
# Can see some looks repetitive.

# %%
query = """
    SELECT 
        company_name, issue, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        company_name, issue
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

issue2_df = query_job.to_dataframe()
issue2_df[:10]
# Out:
#                              company_name  \
# 0     Experian Information Solutions Inc.
# 1                           EQUIFAX, INC.
# 2  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# 3                           EQUIFAX, INC.
# 4     Experian Information Solutions Inc.
# 5  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# 6                           EQUIFAX, INC.
# 7                           EQUIFAX, INC.
# 8  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# 9     Experian Information Solutions Inc.
#
#                                                issue  total
# 0               Incorrect information on your report  22736
# 1               Incorrect information on your report  22273
# 2               Incorrect information on your report  21293
# 3  Problem with a credit reporting company's inve...  11736
# 4  Problem with a credit reporting company's inve...  11282
# 5  Problem with a credit reporting company's inve...  10780
# 6             Incorrect information on credit report   7630
# 7                        Improper use of your report   6743
# 8             Incorrect information on credit report   6427
# 9             Incorrect information on credit report   5765

# %%
query = """
    SELECT 
        subissue, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        subissue
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

subissue_df = query_job.to_dataframe()
subissue_df[:10]
# Out:
#                                             subissue   total
# 0                                               None  132115
# 1                Information belongs to someone else   39397
# 2  Their investigation did not fix an error on yo...   30955
# 3                           Account status incorrect   17371
# 4                      Account information incorrect   16587
# 5                                  Debt is not yours   16148
# 6  Credit inquiries on your report that you don't...   14097
# 7                                      Debt was paid   11722
# 8                                   Debt is not mine   10105
# 9                  Attempted to collect wrong amount    8691

# %% [markdown]
# debt is not mine and debt is not yours seem to be the same thing?

# %%
query = """
    SELECT 
        issue, subissue, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        issue, subissue
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

subissue2_df = query_job.to_dataframe()
subissue2_df[:15]
# Out:
#                                                 issue  \
# 0                Incorrect information on your report
# 1   Problem with a credit reporting company's inve...
# 2                Incorrect information on your report
# 3                Incorrect information on your report
# 4                   Attempts to collect debt not owed
# 5                      Trouble during payment process
# 6            Loan servicing, payments, escrow account
# 7                         Improper use of your report
# 8            Loan modification,collection,foreclosure
# 9               Cont'd attempts collect debt not owed
# 10                         Struggling to pay mortgage
# 11                 False statements or representation
# 12                    Written notification about debt
# 13                              Communication tactics
# 14             Incorrect information on credit report
#
#                                              subissue  total
# 0                 Information belongs to someone else  39397
# 1   Their investigation did not fix an error on yo...  30794
# 2                            Account status incorrect  17371
# 3                       Account information incorrect  16587
# 4                                   Debt is not yours  16148
# 5                                                None  14758
# 6                                                None  14722
# 7   Credit inquiries on your report that you don't...  14097
# 8                                                None  10789
# 9                                    Debt is not mine  10105
# 10                                               None   9129
# 11                  Attempted to collect wrong amount   8691
# 12   Didn't receive enough information to verify debt   8376
# 13                         Frequent or repeated calls   7876
# 14                            Information is not mine   7102

# %% [markdown]
# # Looking At Which Companies Had The Most Complaint

# %%
query = """
    SELECT 
        company_name, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        company_name
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

companies_df = query_job.to_dataframe()
companies_df
# Out:
#                                 company_name  total
# 0                              EQUIFAX, INC.  56784
# 1        Experian Information Solutions Inc.  50088
# 2     TRANSUNION INTERMEDIATE HOLDINGS, INC.  48040
# 3                             CITIBANK, N.A.  17402
# 4                      WELLS FARGO & COMPANY  16972
# ...                                      ...    ...
# 4509                         We Finance Inc.      1
# 4510             ACCEPTANCE CAPITAL MORTGAGE      1
# 4511                 UNIVERSAL LENDING CORP.      1
# 4512                   Keys Auto Finance Inc      1
# 4513                   ACCOUNT SERVICES INC.      1
#
# [4514 rows x 2 columns]

# %%
query = """
    SELECT 
        company_name, COUNT(complaint_id) as total, (COUNT(complaint_id)/1498059)*100 as percentage
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        company_name
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

companies_df2 = query_job.to_dataframe()
companies_df2
# Out:
#                                 company_name  total  percentage
# 0                              EQUIFAX, INC.  56784    3.790505
# 1        Experian Information Solutions Inc.  50088    3.343527
# 2     TRANSUNION INTERMEDIATE HOLDINGS, INC.  48040    3.206816
# 3                             CITIBANK, N.A.  17402    1.161636
# 4                      WELLS FARGO & COMPANY  16972    1.132933
# ...                                      ...    ...         ...
# 4509                         We Finance Inc.      1    0.000067
# 4510             ACCEPTANCE CAPITAL MORTGAGE      1    0.000067
# 4511                 UNIVERSAL LENDING CORP.      1    0.000067
# 4512                   Keys Auto Finance Inc      1    0.000067
# 4513                   ACCOUNT SERVICES INC.      1    0.000067
#
# [4514 rows x 3 columns]

# %%
companies_df2[:10].plot(kind='bar', x='company_name',y='total')

# %% [markdown]
# # Checking if companies have different spellings

# %%
query = """
    SELECT 
        DISTINCT(company_name)
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        company_name LIKE "C%"
    ORDER BY company_name
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

companies_df3 = query_job.to_dataframe()
companies_df3[:30]
# Out:
#                                          company_name
# 0           C & A Mortgage Services of Florence, Inc.
# 1                         C & E Financial Group, Inc.
# 2                        C & M Associates Group, Inc.
# 3                         C & S Auto Enterprises, Inc
# 4                               C B Merchant Services
# 5                            C&F MORTGAGE CORPORATION
# 6                               C&H INVESTMENTS, INC.
# 7                     C. Edwin Walker Attorney at Law
# 8                            C.Tech Collections, Inc.
# 9                                       C/C Financial
# 10                           C2 Financial Corporation
# 11                              CAB Receivables, Inc.
# 12                                 CAC Financial Corp
# 13                             CADENCE BANCORPORATION
# 14                       CAINE & WEINER COMPANY, INC.
# 15  CALCON MUTUAL MORTGAGE LLC DBA ONETRUST HOME L...
# 16                    CALIFORNIA RECOVERY BUREAU, INC
# 17                                         CALM, Inc.
# 18                                  CALVARY PORTFOLIO
# 19                                 CAPITAL CENTER LLC
# 20                  CAPITAL ONE FINANCIAL CORPORATION
# 21                  CAPITAL RESOURCE MANAGEMENT, INC.
# 22               CAPITOL TITLE INSURANCE AGENCY, INC.
# 23                                   CARD Corporation
# 24                         CARDINAL FINANCIAL COMPANY
# 25                                  CARDPLATFORMS LLC
# 26                 CARMEL FINANCIAL CORPORATION, INC.
# 27                  CARRINGTON MORTGAGE SERVICES, LLC
# 28                              CARS Acquisition, LLC
# 29               CARTER-JONES COLLECTION SERVICE, INC

# %% [markdown]
# Doesn't look like there are different named spellings but more analysis could be performed.

# %% [markdown]
# # Looking at the states sorted by most complaints

# %%
query = """
    SELECT 
        state, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        state
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

state_df = query_job.to_dataframe()
state_df
# Out:
#    state  total
# 0     CA  69879
# 1     FL  53742
# 2     TX  48993
# 3     GA  31781
# 4     NY  29968
# ..   ...    ...
# 59    AA     11
# 60    AS      8
# 61    MP      7
# 62    MH      3
# 63    PW      1
#
# [64 rows x 2 columns]

# %% [markdown]
# Looks like data is include from US territories as well.

# %%
state_df[:10].plot(kind='bar', x='state')

# %% [markdown]
# Complaints by state seemed to be correlated by population size.

# %% [markdown]
# # Resolution

# %%
query = """
    SELECT 
        company_public_response, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        company_public_response
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

response_df = query_job.to_dataframe()
response_df[:10]
# Out:
#                              company_public_response   total
# 0                                               None  267040
# 1  Company has responded to the consumer and the ...  186302
# 2  Company believes it acted appropriately as aut...   35366
# 3   Company chooses not to provide a public response   19818
# 4  Company believes the complaint is the result o...    3381
# 5  Company disputes the facts presented in the co...    3296
# 6  Company believes complaint caused principally ...    2359
# 7  Company believes complaint is the result of an...    2343
# 8  Company believes complaint represents an oppor...    1771
# 9  Company can't verify or dispute the facts in t...    1202

# %%
response_df['company_public_response'][2]
# Out:
# 'Company believes it acted appropriately as authorized by contract or law'

# %%
query = """
    SELECT 
        company_name, company_public_response, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        company_name, company_public_response
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

response2_df = query_job.to_dataframe()
response2_df[:10]
# Out:
#                              company_name  \
# 0                           EQUIFAX, INC.
# 1     Experian Information Solutions Inc.
# 2  TRANSUNION INTERMEDIATE HOLDINGS, INC.
# 3                    JPMORGAN CHASE & CO.
# 4                          CITIBANK, N.A.
# 5                 Navient Solutions, LLC.
# 6       CAPITAL ONE FINANCIAL CORPORATION
# 7                   WELLS FARGO & COMPANY
# 8   BANK OF AMERICA, NATIONAL ASSOCIATION
# 9                     SYNCHRONY FINANCIAL
#
#                              company_public_response  total
# 0                                               None  56784
# 1  Company has responded to the consumer and the ...  46531
# 2  Company has responded to the consumer and the ...  44352
# 3                                               None  16389
# 4  Company has responded to the consumer and the ...  14875
# 5                                               None  14200
# 6                                               None  14147
# 7  Company has responded to the consumer and the ...  13863
# 8  Company has responded to the consumer and the ...  13412
# 9  Company has responded to the consumer and the ...   8189

# %%
response2_df[response2_df['company_name']=='EQUIFAX, INC.']
# Out:
#     company_name company_public_response  total
# 0  EQUIFAX, INC.                    None  56784

# %%
response2_df[response2_df['company_name']=='JPMORGAN CHASE & CO.']
# Out:
#               company_name                            company_public_response  \
# 3     JPMORGAN CHASE & CO.                                               None
# 4470  JPMORGAN CHASE & CO.  Company has responded to the consumer and the ...
#
#       total
# 3     16389
# 4470      2

# %%
response2_df[response2_df['company_public_response']=='Company believes it acted appropriately as authorized by contract or law'][:10]
# Out:
#                                company_name  \
# 27                                      ERC
# 31         SELECT PORTFOLIO SERVICING, INC.
# 32   UNITED SERVICES AUTOMOBILE ASSOCIATION
# 39                     Ditech Financial LLC
# 40                NAVY FEDERAL CREDIT UNION
# 60                 Shellpoint Partners, LLC
# 75                              GREAT LAKES
# 82                          SLM CORPORATION
# 102          Phoenix Financial Services LLC
# 115           I.Q. DATA INTERNATIONAL, INC.
#
#                                company_public_response  total
# 27   Company believes it acted appropriately as aut...   2558
# 31   Company believes it acted appropriately as aut...   2216
# 32   Company believes it acted appropriately as aut...   2138
# 39   Company believes it acted appropriately as aut...   1841
# 40   Company believes it acted appropriately as aut...   1811
# 60   Company believes it acted appropriately as aut...   1098
# 75   Company believes it acted appropriately as aut...    721
# 82   Company believes it acted appropriately as aut...    686
# 102  Company believes it acted appropriately as aut...    547
# 115  Company believes it acted appropriately as aut...    466

# %% [markdown]
# # Looking at date

# %%
query = """
    SELECT 
        extract(year from date_received) as year, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
       year
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

year_df = query_job.to_dataframe()

# %%
year_df.sort_values(by='year').plot(x='year')

# %%
year_df.sort_values(by='year')
# Out:
#    year   total
# 4  2015   54753
# 3  2016   77819
# 2  2017  115176
# 1  2018  118487
# 0  2019  124913
# 5  2020   31769

# %% [markdown]
# Data all the way from 2011 but only 2015 and on has consumer complaint narratives. 2020 drops due to not being a full year yet.

# %%
query = """
    SELECT 
        extract(month from date_received) as month, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
       month
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

month_df = query_job.to_dataframe()
month_df.plot(kind='bar', x='month')

# %%
month_df.sort_values(by='month').plot(kind='bar',x='month')

# %%
query = """
    SELECT 
        date_received, COUNT(complaint_id) as total
    FROM 
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
    GROUP BY
        date_received
    ORDER BY
        total DESC
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

time_df = query_job.to_dataframe()
time_df
# Out:
#      date_received  total
# 0       2017-09-08   1890
# 1       2017-09-09   1369
# 2       2017-01-19   1013
# 3       2017-09-13    904
# 4       2017-01-20    809
# ...            ...    ...
# 1858    2020-04-20     35
# 1859    2020-04-19     31
# 1860    2020-04-23     30
# 1861    2020-04-24      6
# 1862    2017-04-22      4
#
# [1863 rows x 2 columns]

# %%
from datetime import datetime
time_df['date_received'] = pandas.to_datetime(time_df['date_received'])
time_df.set_index('date_received', inplace=True)
time_df.head()
# Out:
#                total
# date_received
# 2017-09-08      1890
# 2017-09-09      1369
# 2017-01-19      1013
# 2017-09-13       904
# 2017-01-20       809

# %%
time_df['total'].plot()

# %%
dates = pandas.date_range(start='1/1/2017', end='1/1/2018', freq='D')
time_df.loc[dates]['total'].plot()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike

# %% [markdown]
# Why those spikes?

# %%
dates2 = pandas.date_range(start='1/10/2017', end='1/20/2017', freq='D')
time_df.loc[dates2]['total'].plot()

# %% [markdown]
# Low on the weekends, high on Thursday for this week.
# # Now lets look at the other half of the columns

# %% [markdown]
# These columns look at zipcode, tags, and other variables that describe how the complaint resolved.

# %%
query = """
    SELECT 
        zip_code,
        tags,
        consumer_consent_provided,
        submitted_via,
        date_sent_to_company,
        company_response_to_consumer,
        timely_response,
        consumer_disputed,
        complaint_id
    FROM
        `bigquery-public-data.cfpb_complaints.complaint_database`
    WHERE
        consumer_complaint_narrative IS NOT NULL
"""
query_job = client.query(
    query,
    # Location must match that of the dataset(s) referenced in the query.
    location="US",
)  # API request - starts the query

second_half_df = query_job.to_dataframe()

# %%
second_half_df.describe()
# Out:
#        zip_code           tags consumer_consent_provided submitted_via  \
# count    405613          89720                    522917        522917
# unique    11155              3                         1             1
# top       300XX  Servicemember          Consent provided           Web
# freq       9224          54294                    522917        522917
#
#        date_sent_to_company company_response_to_consumer timely_response  \
# count                522917                       522916          522917
# unique                 1864                            6               2
# top              2017-09-08      Closed with explanation            True
# freq                   1783                       423135          509109
#
#        consumer_disputed complaint_id
# count             164066       522917
# unique                 2       522917
# top                False      2994210
# freq              128259            1

# %%
(second_half_df.isnull().sum()/len(second_half_df)*100).sort_values(ascending=False)
# Out:
# tags                            82.842401
# consumer_disputed               68.624849
# zip_code                        22.432623
# company_response_to_consumer     0.000191
# complaint_id                     0.000000
# timely_response                  0.000000
# date_sent_to_company             0.000000
# submitted_via                    0.000000
# consumer_consent_provided        0.000000
# dtype: float64

# %%
second_half_df['zip_code'].value_counts().head(n=20)
# Out:
# 300XX    9224
# 770XX    6168
# 606XX    5794
# 330XX    5642
# 331XX    5517
# 750XX    5503
# 303XX    4629
# 900XX    4574
# 891XX    4513
# 112XX    4262
# 334XX    4210
# 945XX    4130
# 302XX    4032
# 191XX    3334
# 333XX    3194
# 301XX    3172
# 852XX    3087
# 207XX    3060
# 282XX    2978
# 917XX    2876
# Name: zip_code, dtype: int64

# %% [markdown]
# Looks like part of the zipcode is hidden.

# %% [markdown]
# Tag seems to be a classifier of some sort.

# %%
second_half_df['tags'].value_counts()
# Out:
# Servicemember                    54294
# Older American                   28254
# Older American, Servicemember     7172
# Name: tags, dtype: int64

# %% [markdown]
# Only three groups. What does servicemember mean? What is the age cutoff for older American?

# %%
second_half_df['tags'].value_counts().plot(kind='bar')

# %% [markdown]
# Look at consumer consent

# %%
second_half_df['consumer_consent_provided'].value_counts().plot(kind='bar')

# %% [markdown]
# Only one label for this variable.

# %%
second_half_df['submitted_via'].value_counts().plot(kind='bar')

# %% [markdown]
# All complaints sent through the web.

# %% [markdown]
# ### Possible company responses

# %%
second_half_df['company_response_to_consumer'].value_counts()
# Out:
# Closed with explanation            423135
# Closed with non-monetary relief     65093
# Closed with monetary relief         27658
# Closed                               3741
# Untimely response                    3288
# In progress                             1
# Name: company_response_to_consumer, dtype: int64

# %% [markdown]
# Probably want to put more emphasis on untimely response and closed with monetary relief. Focusing on these resolutions will save the company money and face-value.

# %%
second_half_df['timely_response'].value_counts().plot(kind='bar')

# %%
second_half_df['consumer_disputed'].value_counts().plot(kind='bar')

# %% [markdown]
# Most complaints are resolved in a timely manner and are not disputed.
